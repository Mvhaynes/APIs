# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %% [markdown]
# ### Perform API Calls

# %%
# Import API Key
from api_keys import weather_api_key

# Get API url 
weather_url = "http://api.openweathermap.org/data/2.5/weather?"

# Create empty columns 
weather_df = pd.DataFrame()
weather_df['City'] = cities
weather_df['Lat'] = ""
weather_df['Long'] = ""
weather_df['Max Temp'] = ""
weather_df['Humidity'] = ""
weather_df['Cloudiness'] = ""
weather_df['Wind Speed'] = ""
weather_df['Country'] = ""
weather_df['Date'] = ""

#City name formatting 
weather_df['City'] = weather_df['City'].str.title()

weather_df
# Out:
#               City Lat Long Max Temp Humidity Cloudiness Wind Speed Country  \
# 0          Rikitea
# 1            Tabou
# 2    Mar Del Plata
# 3            Bluff
# 4         Saleaula
# ..             ...  ..  ...      ...      ...        ...        ...     ...
# 599         Jiddah
# 600        Fortuna
# 601       Poddorye
# 602      Karlshamn
# 603  Cockburn Town
#
#     Date
# 0
# 1
# 2
# 3
# 4
# ..   ...
# 599
# 600
# 601
# 602
# 603
#
# [604 rows x 9 columns]

# %%
## API calls 

print('Beginning Data Retrieval')
print('------------------------------------')

# Loop through cities and get weather. Pass if city has no data.
for index, row in weather_df.iterrows():
    
    # Get city name from dataframe 
    city = row['City']
    
    # Generate query url 
    query_url = weather_url + 'q=' + city + '&appid=' + weather_api_key
    
    try:
        # Retrieve data 
        response = requests.get(query_url).json()
        
        # Add response to column 
        print(f"Retrieving results for response {index}: {city}.")
        weather_df.loc[index, 'Lat'] = response['coord']['lat']
        weather_df.loc[index, 'Long'] = response['coord']['lon']
        weather_df.loc[index, 'Max Temp'] = response['main']['temp_max']
        weather_df.loc[index, 'Humidity'] = response['main']['humidity']
        weather_df.loc[index, 'Cloudiness'] = response['clouds']['all']
        weather_df.loc[index, 'Wind Speed'] = response['wind']['speed']
        weather_df.loc[index, 'Country'] = response['sys']['country']
        weather_df.loc[index, 'Date'] = response['dt']
    
    # Skip results with no data
    except KeyError:
        print(f'No Results for {city}... skipping')
    
    
print('------------------------------------')
print('Data Retrieval Complete')
# Out:
# Beginning Data Retrieval
# ------------------------------------
# Retrieving results for response 0: Rikitea.
# Retrieving results for response 1: Tabou.
# Retrieving results for response 2: Mar Del Plata.
# Retrieving results for response 3: Bluff.
# Retrieving results for response 4: Saleaula.
# No Results for Saleaula... skipping
# Retrieving results for response 5: Dingle.
# Retrieving results for response 6: Qaanaaq.
# Retrieving results for response 7: Christchurch.
# Retrieving results for response 8: Puerto Ayora.
# Retrieving results for response 9: Sorong.
# Retrieving results for response 10: Illoqqortoormiut.
# No Results for Illoqqortoormiut... skipping
# Retrieving results for response 11: Kaitangata.
# Retrieving results for response 12: San Patricio.
# Retrieving results for response 13: Tidore.
# No Results for Tidore... skipping
# Retrieving results for response 14: Albany.
# Retrieving results for response 15: Valdez.
# Retrieving results for response 16: Barentsburg.
# No Results for Barentsburg... skipping
# Retrieving results for response 17: Port-Gentil.
# Retrieving results for response 18: Punta Arenas.
# Retrieving results for response 19: Ponta Do Sol.
# Retrieving results for response 20: Amderma.
# No Results for Amderma... skipping
# Retrieving results for response 21: Zavodouspenskoye.
# Retrieving results for response 22: Lavrentiya.
# Retrieving results for response 23: Atuona.
# Retrieving results for response 24: Ushuaia.
# Retrieving results for response 25: Tres Lagoas.
# Retrieving results for response 26: Lieksa.
# Retrieving results for response 27: Mamlyutka.
# Retrieving results for response 28: Georgetown.
# Retrieving results for response 29: Waddan.
# Retrieving results for response 30: Berlevag.
# Retrieving results for response 31: Aklavik.
# Retrieving results for response 32: Meiganga.
# Retrieving results for response 33: Inderborskiy.
# No Results for Inderborskiy... skipping
# Retrieving results for response 34: Fairbanks.
# Retrieving results for response 35: Busselton.
# Retrieving results for response 36: Kouroussa.
# Retrieving results for response 37: Dharchula.
# Retrieving results for response 38: Gulu.
# Retrieving results for response 39: Port Lincoln.
# Retrieving results for response 40: Tuktoyaktuk.
# Retrieving results for response 41: Camacari.
# Retrieving results for response 42: Port Elizabeth.
# Retrieving results for response 43: Mataura.
# Retrieving results for response 44: Quincy.
# Retrieving results for response 45: Dikson.
# Retrieving results for response 46: Tupelo.
# Retrieving results for response 47: Lakes Entrance.
# Retrieving results for response 48: Hithadhoo.
# Retrieving results for response 49: Hermanus.
# Retrieving results for response 50: Cidreira.
# Retrieving results for response 51: Salinas.
# Retrieving results for response 52: Hofn.
# Retrieving results for response 53: Bethel.
# Retrieving results for response 54: Vastseliina.
# Retrieving results for response 55: Stokmarknes.
# Retrieving results for response 56: Lasa.
# Retrieving results for response 57: Sentyabrskiy.
# No Results for Sentyabrskiy... skipping
# Retrieving results for response 58: Tarko-Sale.
# Retrieving results for response 59: Alta Floresta.
# Retrieving results for response 60: Nueva Loja.
# Retrieving results for response 61: Isangel.
# Retrieving results for response 62: Coquimbo.
# Retrieving results for response 63: Talnakh.
# Retrieving results for response 64: Khatanga.
# Retrieving results for response 65: Souillac.
# Retrieving results for response 66: Kiruna.
# Retrieving results for response 67: Tiksi.
# Retrieving results for response 68: Half Moon Bay.
# Retrieving results for response 69: Bengkulu.
# Retrieving results for response 70: Sinnamary.
# Retrieving results for response 71: Saskylakh.
# Retrieving results for response 72: Quipile.
# Retrieving results for response 73: Vanimo.
# Retrieving results for response 74: Cape Town.
# Retrieving results for response 75: Saldanha.
# Retrieving results for response 76: Champerico.
# Retrieving results for response 77: La Ronge.
# Retrieving results for response 78: Port Blair.
# Retrieving results for response 79: Pitimbu.
# Retrieving results for response 80: Manaus.
# Retrieving results for response 81: Aljezur.
# Retrieving results for response 82: Port Alfred.
# Retrieving results for response 83: Belushya Guba.
# No Results for Belushya Guba... skipping
# Retrieving results for response 84: Namibe.
# Retrieving results for response 85: Mombaca.
# Retrieving results for response 86: Brae.
# Retrieving results for response 87: Sibolga.
# Retrieving results for response 88: Walvis Bay.
# Retrieving results for response 89: Havelock.
# Retrieving results for response 90: Klamath Falls.
# Retrieving results for response 91: Abbeville.
# Retrieving results for response 92: Guerrero Negro.
# Retrieving results for response 93: Bargal.
# No Results for Bargal... skipping
# Retrieving results for response 94: Kupang.
# Retrieving results for response 95: Butaritari.
# Retrieving results for response 96: Destin.
# Retrieving results for response 97: Jamestown.
# Retrieving results for response 98: Portland.
# Retrieving results for response 99: Lebu.
# Retrieving results for response 100: Udachnyy.
# Retrieving results for response 101: Amapa.
# Retrieving results for response 102: Ferme-Neuve.
# Retrieving results for response 103: Maceio.
# Retrieving results for response 104: Hobart.
# Retrieving results for response 105: Loreto.
# Retrieving results for response 106: Richards Bay.
# Retrieving results for response 107: Mizdah.
# Retrieving results for response 108: Tuatapere.
# Retrieving results for response 109: Norman Wells.
# Retrieving results for response 110: Makakilo City.
# Retrieving results for response 111: Attawapiskat.
# No Results for Attawapiskat... skipping
# Retrieving results for response 112: Longfeng.
# Retrieving results for response 113: New Norfolk.
# Retrieving results for response 114: Alofi.
# Retrieving results for response 115: Vaini.
# Retrieving results for response 116: Tasiilaq.
# Retrieving results for response 117: Lazaro Cardenas.
# Retrieving results for response 118: Asfi.
# Retrieving results for response 119: Esperance.
# Retrieving results for response 120: Tumannyy.
# No Results for Tumannyy... skipping
# Retrieving results for response 121: Kruisfontein.
# Retrieving results for response 122: Carnarvon.
# Retrieving results for response 123: Kapaa.
# Retrieving results for response 124: Klaksvik.
# Retrieving results for response 125: Mangalia.
# Retrieving results for response 126: Taolanaro.
# No Results for Taolanaro... skipping
# Retrieving results for response 127: Porto Novo.
# Retrieving results for response 128: Faanui.
# Retrieving results for response 129: Emerald.
# Retrieving results for response 130: Vaitupu.
# No Results for Vaitupu... skipping
# Retrieving results for response 131: Bathsheba.
# Retrieving results for response 132: Port Hardy.
# Retrieving results for response 133: San Cristobal.
# Retrieving results for response 134: Korla.
# Retrieving results for response 135: Bredasdorp.
# Retrieving results for response 136: Saint-Philippe.
# Retrieving results for response 137: Soyo.
# Retrieving results for response 138: Miyako.
# Retrieving results for response 139: Aksarayskiy.
# Retrieving results for response 140: Clarksdale.
# Retrieving results for response 141: Ilulissat.
# Retrieving results for response 142: Karpathos.
# Retrieving results for response 143: Andradas.
# Retrieving results for response 144: Ancud.
# Retrieving results for response 145: Fort Saint James.
# Retrieving results for response 146: Bantry.
# Retrieving results for response 147: Kholtoson.
# Retrieving results for response 148: Sungai Siput Utara.
# No Results for Sungai Siput Utara... skipping
# Retrieving results for response 149: Samoylovka.
# Retrieving results for response 150: Castro.
# Retrieving results for response 151: Vostok.
# Retrieving results for response 152: Bereda.
# Retrieving results for response 153: Gao.
# Retrieving results for response 154: Formoso Do Araguaia.
# No Results for Formoso Do Araguaia... skipping
# Retrieving results for response 155: Itarema.
# Retrieving results for response 156: Necochea.
# Retrieving results for response 157: Meyungs.
# No Results for Meyungs... skipping
# Retrieving results for response 158: Guiratinga.
# Retrieving results for response 159: Taltal.
# Retrieving results for response 160: Narsaq.
# Retrieving results for response 161: Pelham.
# Retrieving results for response 162: Chuy.
# Retrieving results for response 163: Jinka.
# Retrieving results for response 164: Warrington.
# Retrieving results for response 165: East London.
# Retrieving results for response 166: Hilo.
# Retrieving results for response 167: Broken Hill.
# Retrieving results for response 168: Beringovskiy.
# Retrieving results for response 169: Buraydah.
# Retrieving results for response 170: Morondava.
# Retrieving results for response 171: Cherskiy.
# Retrieving results for response 172: Diamantino.
# Retrieving results for response 173: Piterka.
# Retrieving results for response 174: The Pas.
# Retrieving results for response 175: Palabuhanratu.
# No Results for Palabuhanratu... skipping
# Retrieving results for response 176: Provideniya.
# Retrieving results for response 177: Caravelas.
# Retrieving results for response 178: Baruun-Urt.
# Retrieving results for response 179: Adre.
# Retrieving results for response 180: Pontes E Lacerda.
# Retrieving results for response 181: Barrow.
# Retrieving results for response 182: Faya.
# Retrieving results for response 183: Bagan.
# Retrieving results for response 184: Superior.
# Retrieving results for response 185: Peniche.
# Retrieving results for response 186: El Faiyum.
# No Results for El Faiyum... skipping
# Retrieving results for response 187: Sao Joao Da Barra.
# Retrieving results for response 188: Sao Lourenco Do Sul.
# Retrieving results for response 189: Kavieng.
# Retrieving results for response 190: Calabozo.
# Retrieving results for response 191: Mayo.
# Retrieving results for response 192: Gayny.
# Retrieving results for response 193: Arraial Do Cabo.
# Retrieving results for response 194: Pevek.
# Retrieving results for response 195: Ahipara.
# Retrieving results for response 196: Itacare.
# Retrieving results for response 197: Gat.
# Retrieving results for response 198: Longyearbyen.
# Retrieving results for response 199: Kot Addu.
# Retrieving results for response 200: Ust-Kulom.
# Retrieving results for response 201: Muscat.
# Retrieving results for response 202: Morant Bay.
# Retrieving results for response 203: Pemangkat.
# Retrieving results for response 204: Victoria.
# Retrieving results for response 205: Kendari.
# Retrieving results for response 206: Chokurdakh.
# Retrieving results for response 207: Silver City.
# Retrieving results for response 208: Saint George.
# Retrieving results for response 209: Avarua.
# Retrieving results for response 210: Puerto Baquerizo Moreno.
# Retrieving results for response 211: Yellowknife.
# Retrieving results for response 212: Grand River South East.
# No Results for Grand River South East... skipping
# Retrieving results for response 213: Yarada.
# Retrieving results for response 214: Tautira.
# Retrieving results for response 215: Airai.
# Retrieving results for response 216: Touros.
# Retrieving results for response 217: Bolungarvik.
# No Results for Bolungarvik... skipping
# Retrieving results for response 218: Margate.
# Retrieving results for response 219: Nikolskoye.
# Retrieving results for response 220: Tiznit.
# Retrieving results for response 221: Labuhan.
# Retrieving results for response 222: Maragogi.
# Retrieving results for response 223: Yeletskiy.
# No Results for Yeletskiy... skipping
# Retrieving results for response 224: Kamina.
# Retrieving results for response 225: Quzhou.
# Retrieving results for response 226: Vikravandi.
# Retrieving results for response 227: Ploemeur.
# Retrieving results for response 228: Bada.
# Retrieving results for response 229: Tsihombe.
# No Results for Tsihombe... skipping
# Retrieving results for response 230: Mahebourg.
# Retrieving results for response 231: Vestmannaeyjar.
# Retrieving results for response 232: Alice Springs.
# Retrieving results for response 233: Ostrovnoy.
# Retrieving results for response 234: Fergus Falls.
# Retrieving results for response 235: Torbat-E Jam.
# Retrieving results for response 236: Luderitz.
# Retrieving results for response 237: La Macarena.
# Retrieving results for response 238: Messias.
# Retrieving results for response 239: Inhambane.
# Retrieving results for response 240: Saint-Augustin.
# Retrieving results for response 241: Carupano.
# Retrieving results for response 242: Cabo San Lucas.
# Retrieving results for response 243: Kodiak.
# Retrieving results for response 244: Bentong.
# Retrieving results for response 245: Teguldet.
# Retrieving results for response 246: Eyl.
# Retrieving results for response 247: Yaan.
# Retrieving results for response 248: Gardelegen.
# Retrieving results for response 249: Shevchenkove.
# Retrieving results for response 250: Cairns.
# Retrieving results for response 251: Tashtyp.
# Retrieving results for response 252: Quirinopolis.
# Retrieving results for response 253: Quatre Cocos.
# Retrieving results for response 254: Padang.
# Retrieving results for response 255: Herat.
# Retrieving results for response 256: Iqaluit.
# Retrieving results for response 257: Surt.
# Retrieving results for response 258: Barkly West.
# Retrieving results for response 259: Maxixe.
# Retrieving results for response 260: Arlit.
# Retrieving results for response 261: Cururupu.
# Retrieving results for response 262: Ixtapa.
# Retrieving results for response 263: Newport.
# Retrieving results for response 264: Mayari.
# No Results for Mayari... skipping
# Retrieving results for response 265: Auki.
# Retrieving results for response 266: Dolbeau.
# No Results for Dolbeau... skipping
# Retrieving results for response 267: North Bend.
# Retrieving results for response 268: Leh.
# Retrieving results for response 269: Hambantota.
# Retrieving results for response 270: Dabou.
# Retrieving results for response 271: La Ciotat.
# Retrieving results for response 272: Tsabong.
# Retrieving results for response 273: Upernavik.
# Retrieving results for response 274: Killybegs.
# Retrieving results for response 275: The Valley.
# Retrieving results for response 276: Solnechnyy.
# Retrieving results for response 277: Kieta.
# Retrieving results for response 278: Jibuti.
# Retrieving results for response 279: Lancaster.
# Retrieving results for response 280: Mangaluru.
# Retrieving results for response 281: Saint Anthony.
# Retrieving results for response 282: Halalo.
# No Results for Halalo... skipping
# Retrieving results for response 283: Muroto.
# Retrieving results for response 284: Samusu.
# No Results for Samusu... skipping
# Retrieving results for response 285: Catabola.
# Retrieving results for response 286: Anadyr.
# Retrieving results for response 287: Vitimskiy.
# No Results for Vitimskiy... skipping
# Retrieving results for response 288: Nieuw Amsterdam.
# Retrieving results for response 289: Uturoa.
# Retrieving results for response 290: Bolshaya Martynovka.
# Retrieving results for response 291: Dunedin.
# Retrieving results for response 292: Evensk.
# Retrieving results for response 293: Jaque.
# Retrieving results for response 294: Stantsionno-Oyashinskiy.
# Retrieving results for response 295: Mehamn.
# Retrieving results for response 296: Katsuura.
# Retrieving results for response 297: Leningradskiy.
# Retrieving results for response 298: Shwebo.
# Retrieving results for response 299: Yumen.
# Retrieving results for response 300: Mazamari.
# Retrieving results for response 301: Dillon.
# Retrieving results for response 302: Japura.
# Retrieving results for response 303: Marawi.
# Retrieving results for response 304: Duekoue.
# Retrieving results for response 305: Santa Rosa.
# Retrieving results for response 306: Aksarka.
# Retrieving results for response 307: Halifax.
# Retrieving results for response 308: Sompeta.
# Retrieving results for response 309: Te Anau.
# Retrieving results for response 310: Yulara.
# Retrieving results for response 311: Toungoo.
# No Results for Toungoo... skipping
# Retrieving results for response 312: Birin.
# Retrieving results for response 313: Clonakilty.
# Retrieving results for response 314: Barabai.
# Retrieving results for response 315: Umm Lajj.
# Retrieving results for response 316: Ribeira Grande.
# Retrieving results for response 317: Namtsy.
# Retrieving results for response 318: Deputatskiy.
# Retrieving results for response 319: Bandipur.
# Retrieving results for response 320: Akyab.
# Retrieving results for response 321: Ngunguru.
# Retrieving results for response 322: Kushima.
# Retrieving results for response 323: Hulyaypole.
# Retrieving results for response 324: Rio Grande.
# Retrieving results for response 325: Moree.
# Retrieving results for response 326: Payo.
# Retrieving results for response 327: Sovetskiy.
# Retrieving results for response 328: Vardo.
# Retrieving results for response 329: Nizhneyansk.
# No Results for Nizhneyansk... skipping
# Retrieving results for response 330: Naron.
# Retrieving results for response 331: Opobo.
# No Results for Opobo... skipping
# Retrieving results for response 332: Sorland.
# Retrieving results for response 333: Kautokeino.
# Retrieving results for response 334: Puerto Escondido.
# Retrieving results for response 335: Kangaatsiaq.
# Retrieving results for response 336: Cartagena.
# Retrieving results for response 337: Sumbawa.
# No Results for Sumbawa... skipping
# Retrieving results for response 338: Hamilton.
# Retrieving results for response 339: Cuorgne.
# Retrieving results for response 340: Dalvik.
# Retrieving results for response 341: Porto Walter.
# Retrieving results for response 342: Tianpeng.
# Retrieving results for response 343: Lolua.
# No Results for Lolua... skipping
# Retrieving results for response 344: Manitouwadge.
# Retrieving results for response 345: Baie-Comeau.
# Retrieving results for response 346: Concordia.
# Retrieving results for response 347: Biggar.
# Retrieving results for response 348: Tabas.
# Retrieving results for response 349: Yar-Sale.
# Retrieving results for response 350: Bartica.
# Retrieving results for response 351: Komsomolskiy.
# Retrieving results for response 352: Linxia.
# Retrieving results for response 353: Ardakan.
# Retrieving results for response 354: Chabahar.
# Retrieving results for response 355: Bonthe.
# Retrieving results for response 356: Sete.
# Retrieving results for response 357: Paskov.
# Retrieving results for response 358: Eirunepe.
# Retrieving results for response 359: Farim.
# Retrieving results for response 360: Geraldton.
# Retrieving results for response 361: Constitucion.
# Retrieving results for response 362: Boende.
# Retrieving results for response 363: Angoram.
# Retrieving results for response 364: Samalaeulu.
# No Results for Samalaeulu... skipping
# Retrieving results for response 365: Mys Shmidta.
# No Results for Mys Shmidta... skipping
# Retrieving results for response 366: Kota Bahru.
# Retrieving results for response 367: Three Hills.
# Retrieving results for response 368: Severo-Kurilsk.
# Retrieving results for response 369: Coronel Vivida.
# Retrieving results for response 370: Mogadishu.
# Retrieving results for response 371: Znamenskoye.
# Retrieving results for response 372: Hualmay.
# Retrieving results for response 373: Konevo.
# Retrieving results for response 374: Basco.
# Retrieving results for response 375: Clyde River.
# Retrieving results for response 376: Denia.
# Retrieving results for response 377: Owosso.
# Retrieving results for response 378: Ekuvukeni.
# Retrieving results for response 379: Sarakhs.
# Retrieving results for response 380: Coahuayana.
# Retrieving results for response 381: Serra Talhada.
# Retrieving results for response 382: Oktyabrskiy.
# Retrieving results for response 383: Aripuana.
# Retrieving results for response 384: Sioux Lookout.
# Retrieving results for response 385: Nhulunbuy.
# Retrieving results for response 386: Bubaque.
# Retrieving results for response 387: Acari.
# Retrieving results for response 388: Valle Hermoso.
# Retrieving results for response 389: Kargasok.
# Retrieving results for response 390: Pisco.
# Retrieving results for response 391: West Bay.
# Retrieving results for response 392: Belmonte.
# Retrieving results for response 393: Santa Eulalia.
# Retrieving results for response 394: Thompson.
# Retrieving results for response 395: Naro.
# Retrieving results for response 396: La Libertad.
# Retrieving results for response 397: Namatanai.
# Retrieving results for response 398: Tarland.
# No Results for Tarland... skipping
# Retrieving results for response 399: Timra.
# Retrieving results for response 400: Qasigiannguit.
# Retrieving results for response 401: Malinovoye Ozero.
# Retrieving results for response 402: Kushikino.
# Retrieving results for response 403: Pandan.
# Retrieving results for response 404: Ruatoria.
# No Results for Ruatoria... skipping
# Retrieving results for response 405: Tessalit.
# Retrieving results for response 406: Welkom.
# Retrieving results for response 407: Pochutla.
# Retrieving results for response 408: Hami.
# Retrieving results for response 409: Bandarbeyla.
# Retrieving results for response 410: Lamar.
# Retrieving results for response 411: Nguiu.
# No Results for Nguiu... skipping
# Retrieving results for response 412: Ayame.
# Retrieving results for response 413: Saint-Leu.
# Retrieving results for response 414: Nanortalik.
# Retrieving results for response 415: Comodoro Rivadavia.
# Retrieving results for response 416: Iralaya.
# Retrieving results for response 417: Mago.
# Retrieving results for response 418: Sitka.
# Retrieving results for response 419: Manjacaze.
# Retrieving results for response 420: Porbandar.
# Retrieving results for response 421: Hirara.
# Retrieving results for response 422: Kathu.
# Retrieving results for response 423: Chagda.
# No Results for Chagda... skipping
# Retrieving results for response 424: Liverpool.
# Retrieving results for response 425: Los Llanos De Aridane.
# Retrieving results for response 426: Hobyo.
# Retrieving results for response 427: Yarkovo.
# Retrieving results for response 428: Horsham.
# Retrieving results for response 429: Sanary-Sur-Mer.
# Retrieving results for response 430: Kahului.
# Retrieving results for response 431: Ayan.
# Retrieving results for response 432: Valparaiso.
# Retrieving results for response 433: Kavaratti.
# Retrieving results for response 434: Mendi.
# Retrieving results for response 435: Ambon.
# Retrieving results for response 436: Angra.
# No Results for Angra... skipping
# Retrieving results for response 437: Nuuk.
# Retrieving results for response 438: Nalut.
# Retrieving results for response 439: Whitehorse.
# Retrieving results for response 440: Mandalgovi.
# Retrieving results for response 441: Mwense.
# Retrieving results for response 442: Kawalu.
# Retrieving results for response 443: Saint-Francois.
# Retrieving results for response 444: Ust-Omchug.
# Retrieving results for response 445: Union.
# Retrieving results for response 446: Karaul.
# No Results for Karaul... skipping
# Retrieving results for response 447: Yerbogachen.
# Retrieving results for response 448: Port Hedland.
# Retrieving results for response 449: Mnogovershinnyy.
# Retrieving results for response 450: Kimbe.
# Retrieving results for response 451: Tapes.
# Retrieving results for response 452: Mount Isa.
# Retrieving results for response 453: Kongolo.
# Retrieving results for response 454: Rocha.
# Retrieving results for response 455: Mount Pleasant.
# Retrieving results for response 456: Lagoa.
# Retrieving results for response 457: Vallenar.
# Retrieving results for response 458: Kathmandu.
# Retrieving results for response 459: Vaitape.
# Retrieving results for response 460: Mosquera.
# Retrieving results for response 461: Cabatuan.
# Retrieving results for response 462: Jamame.
# Retrieving results for response 463: Lorengau.
# Retrieving results for response 464: Twin Falls.
# Retrieving results for response 465: Linhares.
# Retrieving results for response 466: Toamasina.
# Retrieving results for response 467: Otane.
# Retrieving results for response 468: Teya.
# Retrieving results for response 469: Yenagoa.
# Retrieving results for response 470: Torbay.
# Retrieving results for response 471: Vyatskiye Polyany.
# Retrieving results for response 472: Saint-Joseph.
# Retrieving results for response 473: Lar Gerd.
# No Results for Lar Gerd... skipping
# Retrieving results for response 474: Calvinia.
# Retrieving results for response 475: Baykit.
# Retrieving results for response 476: Pangnirtung.
# Retrieving results for response 477: Kenai.
# Retrieving results for response 478: Srednekolymsk.
# Retrieving results for response 479: Taoudenni.
# Retrieving results for response 480: Rio Gallegos.
# Retrieving results for response 481: Krasnogorskiy.
# Retrieving results for response 482: Sao Filipe.
# Retrieving results for response 483: Santa Clara.
# Retrieving results for response 484: Kousseri.
# Retrieving results for response 485: Amberley.
# Retrieving results for response 486: Rossland.
# Retrieving results for response 487: Sinkat.
# No Results for Sinkat... skipping
# Retrieving results for response 488: Mount Gambier.
# Retrieving results for response 489: Yantal.
# Retrieving results for response 490: Arrecife.
# Retrieving results for response 491: Nikolsk.
# Retrieving results for response 492: Cabimas.
# Retrieving results for response 493: Biak.
# Retrieving results for response 494: Pailon.
# Retrieving results for response 495: Arman.
# Retrieving results for response 496: Gigmoto.
# Retrieving results for response 497: Karratha.
# Retrieving results for response 498: Nemuro.
# Retrieving results for response 499: Lata.
# Retrieving results for response 500: Cuiluan.
# Retrieving results for response 501: Vestmanna.
# Retrieving results for response 502: Haines Junction.
# Retrieving results for response 503: Carutapera.
# Retrieving results for response 504: Moose Factory.
# Retrieving results for response 505: Saint-Pierre.
# Retrieving results for response 506: Villa Oliva.
# No Results for Villa Oliva... skipping
# Retrieving results for response 507: Vvedenka.
# Retrieving results for response 508: Coihaique.
# Retrieving results for response 509: Elko.
# Retrieving results for response 510: Trairi.
# Retrieving results for response 511: Camopi.
# Retrieving results for response 512: Pangai.
# Retrieving results for response 513: Maldonado.
# Retrieving results for response 514: Broome.
# Retrieving results for response 515: Valente.
# Retrieving results for response 516: Tromso.
# Retrieving results for response 517: Krasnyy Yar.
# Retrieving results for response 518: Rawson.
# Retrieving results for response 519: Phumi Samraong.
# No Results for Phumi Samraong... skipping
# Retrieving results for response 520: Kambove.
# Retrieving results for response 521: Gaborone.
# Retrieving results for response 522: Mujiayingzi.
# Retrieving results for response 523: Yinchuan.
# Retrieving results for response 524: Huarmey.
# Retrieving results for response 525: Piacabucu.
# Retrieving results for response 526: Rey Bouba.
# Retrieving results for response 527: Wangou.
# Retrieving results for response 528: Flin Flon.
# Retrieving results for response 529: Mahon.
# Retrieving results for response 530: Victor Harbor.
# Retrieving results for response 531: Goderich.
# Retrieving results for response 532: Bilma.
# Retrieving results for response 533: Wajima.
# Retrieving results for response 534: Alyangula.
# Retrieving results for response 535: Biltine.
# Retrieving results for response 536: Raudeberg.
# Retrieving results for response 537: Kilosa.
# Retrieving results for response 538: Mlimba.
# Retrieving results for response 539: Pontian Kecil.
# Retrieving results for response 540: Benoy.
# Retrieving results for response 541: Picton.
# Retrieving results for response 542: Zarate.
# Retrieving results for response 543: Pacific Grove.
# Retrieving results for response 544: Tonantins.
# Retrieving results for response 545: Susurluk.
# Retrieving results for response 546: Tarakan.
# Retrieving results for response 547: Warmbad.
# Retrieving results for response 548: Praia Da Vitoria.
# Retrieving results for response 549: Gunnedah.
# Retrieving results for response 550: Cap Malheureux.
# Retrieving results for response 551: Moroni.
# Retrieving results for response 552: Willowmore.
# Retrieving results for response 553: Boffa.
# Retrieving results for response 554: Matara.
# Retrieving results for response 555: Eldorado.
# Retrieving results for response 556: Burkburnett.
# Retrieving results for response 557: Illintsi.
# Retrieving results for response 558: Daru.
# Retrieving results for response 559: Husavik.
# Retrieving results for response 560: Hacari.
# Retrieving results for response 561: Oum Hadjer.
# Retrieving results for response 562: Hasaki.
# Retrieving results for response 563: Manuk Mangkaw.
# Retrieving results for response 564: Qostanay.
# Retrieving results for response 565: Myitkyina.
# Retrieving results for response 566: Vilhena.
# Retrieving results for response 567: Dmitriyevka.
# Retrieving results for response 568: Naze.
# Retrieving results for response 569: Bom Jesus.
# Retrieving results for response 570: Nouadhibou.
# Retrieving results for response 571: Gizo.
# Retrieving results for response 572: Noumea.
# Retrieving results for response 573: Kerrville.
# Retrieving results for response 574: Mahajanga.
# Retrieving results for response 575: Asau.
# Retrieving results for response 576: Petrykivka.
# Retrieving results for response 577: Meulaboh.
# Retrieving results for response 578: Elizabeth City.
# Retrieving results for response 579: Mackay.
# Retrieving results for response 580: Muriwai Beach.
# Retrieving results for response 581: Ishimbay.
# Retrieving results for response 582: Naberera.
# Retrieving results for response 583: Skjervoy.
# Retrieving results for response 584: Ilo.
# Retrieving results for response 585: Skalistyy.
# No Results for Skalistyy... skipping
# Retrieving results for response 586: Mtsensk.
# Retrieving results for response 587: Xiaoweizhai.
# Retrieving results for response 588: Goundam.
# Retrieving results for response 589: Bucerias.
# Retrieving results for response 590: Pleasanton.
# Retrieving results for response 591: Jalu.
# Retrieving results for response 592: Katherine.
# Retrieving results for response 593: Boddam.
# Retrieving results for response 594: Bobicesti.
# Retrieving results for response 595: Fort Nelson.
# Retrieving results for response 596: Paita.
# Retrieving results for response 597: Arkhangelsk.
# Retrieving results for response 598: Zhigansk.
# Retrieving results for response 599: Jiddah.
# No Results for Jiddah... skipping
# Retrieving results for response 600: Fortuna.
# Retrieving results for response 601: Poddorye.
# Retrieving results for response 602: Karlshamn.
# Retrieving results for response 603: Cockburn Town.
# ------------------------------------
# Data Retrieval Complete

# %%
# Export as csv file 
weather_df.to_csv(output_data_file)

# Display dataframe 
weather_df
# Out:
#               City      Lat     Long Max Temp Humidity Cloudiness Wind Speed  \
# 0          Rikitea -23.1203 -134.969   299.36       69          1       5.31
# 1            Tabou    4.423  -7.3528   299.27       90         21       3.47
# 2    Mar Del Plata -38.0023 -57.5575   296.15       53          0        3.6
# 3            Bluff    -46.6  168.333    288.1       74         66       1.53
# 4         Saleaula
# ..             ...      ...      ...      ...      ...        ...        ...
# 599         Jiddah
# 600        Fortuna  40.5982 -124.157   286.48       71          1        7.2
# 601       Poddorye  57.4695  31.1156   257.69       93        100       3.22
# 602      Karlshamn  56.1706  14.8619   263.71       92         20       5.14
# 603  Cockburn Town  21.4612 -71.1419   300.15       69         40       5.14
#
#     Country        Date
# 0        PF  1612564613
# 1        CI  1612564805
# 2        AR  1612564641
# 3        NZ  1612564805
# 4
# ..      ...         ...
# 599
# 600      US  1612564617
# 601      RU  1612564895
# 602      SE  1612564895
# 603      TC  1612564896
#
# [604 rows x 9 columns]

# %%
# Convert data types to numerical and get statistical summary 
numerical_df = weather_df[['Lat', 'Long', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date']]
numerical_df = numerical_df.apply(pd.to_numeric)
numerical_df.describe().round(2)
# Out:
#           Lat    Long  Max Temp  Humidity  Cloudiness  Wind Speed  \
# count  558.00  558.00    558.00    558.00      558.00      558.00
# mean    18.39   13.37    284.15     74.69       56.52        3.87
# std     33.78   88.97     16.95     19.84       38.48        2.67
# min    -54.80 -175.20    230.15     10.00        0.00        0.09
# 25%     -9.60  -63.21    274.19     66.00       20.00        1.79
# 50%     20.17   15.40    290.45     80.00       75.00        3.36
# 75%     47.73   88.14    297.74     89.00       91.75        5.52
# max     78.22  179.32    304.50    100.00      100.00       14.92
#
#                Date
# count  5.580000e+02
# mean   1.612565e+09
# std    1.137800e+02
# min    1.612564e+09
# 25%    1.612565e+09
# 50%    1.612565e+09
# 75%    1.612565e+09
# max    1.612565e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100% and drop by index if there are any outliers.

high_humid = numerical_df.loc[numerical_df['Humidity'] > 100].index

if len(high_humid) == 0:
    print('No cities have a humidity > 100%')
if len(high_humid) > 0:
    weather_df = weather_df.drop(high_humid)
    display(weather_df)
# Out:
# No cities have a humidity > 100%

# %% [markdown]
# ## Plotting the Data

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Get X and Y values
latitude = numerical_df['Lat']
temp = numerical_df['Max Temp']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(latitude, temp, marker='.', color='red')
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (K)')
plt.grid(True)

# Save as png 
plt.savefig('../output_data/lat_temp.png', format='png')

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Get humidity data
humidity = numerical_df['Humidity']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(latitude, humidity, marker='.', color='orange')
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Save as png 
plt.savefig('../output_data/lat_humid.png', format='png')

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Get cloudiness data
clouds = numerical_df['Cloudiness']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(latitude, clouds, marker='.', color='green')
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Save as png 
plt.savefig('../output_data/lat_cloud.png', format='png')

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Get wind speed data
wind = numerical_df['Wind Speed']

# Plot 
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(latitude, wind, marker='.', color='b')
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid(True)

# Save as png 
plt.savefig('../output_data/lat_wind.png', format='png')

plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Select Northern Hemisphere data
north = numerical_df.loc[numerical_df['Lat'] > 0]

# Get NH Max temp and latitude and convert to farenheit
north_temp = north['Max Temp']
north_temp_f = (north_temp - 273.15) * 9/5 + 32
north_lat = north['Lat']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(north_lat, north_temp_f, marker='.', color='red')
plt.title('Northern Hemisphere City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(True)

# Regression
r_sq = st.pearsonr(north_lat, north_temp_f)
r_sq = r_sq[0].round(2)
NH_temp_r = f"r² = {r_sq}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(north_lat, north_temp_f)
north_temp_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
regression = north_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(north_lat, regression)
plt.annotate(north_temp_eq, (50,80), fontsize=12, color='black')
plt.annotate(NH_temp_r, (50,70), fontsize=12, color='black')


# Save as png 
plt.savefig('../output_data/NH_temp.png', format='png')

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Select Northern Hemisphere data
south = numerical_df.loc[numerical_df['Lat'] < 0]

# Get NH Max temp and latitude and convert to F
south_temp = south['Max Temp']
south_temp = (south_temp - 273.15) * 9/5 + 32
south_lat = south['Lat']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(south_lat, south_temp, marker='.', color='red')
plt.title('Southern Hemisphere City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(True)

# Regression
s_r_sq = st.pearsonr(south_lat, south_temp)
s_r_sq = s_r_sq[0].round(2)
sh_temp_r = f"r² = {s_r_sq}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(south_lat, south_temp)
south_temp_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
sh_regression = south_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(south_lat, sh_regression)
plt.annotate(south_temp_eq, (-50,85), fontsize=12, color='black')
plt.annotate(sh_temp_r, (-50,80), fontsize=12, color='black')


# Save as png 
plt.savefig('../output_data/SH_temp.png', format='png')

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Get NH humidity 
nh_humidity = north['Humidity']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(north_lat, nh_humidity, marker='.', color='orange')
plt.title('Northern Hemisphere City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Regression
nh_hum_r = st.pearsonr(north_lat, nh_humidity)
nh_hum_r = nh_hum_r[0].round(2)
nh_hum_r = f"r² = {nh_hum_r}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(north_lat, nh_humidity)
nh_hum_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
nh_hum_regress = north_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(north_lat, nh_hum_regress)
plt.annotate(nh_hum_eq, (50,40), fontsize=14, color='black')
plt.annotate(nh_hum_r, (50,35), fontsize=14, color='black')


# Save as png 
plt.savefig('../output_data/NH_humidity.png', format='png')

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Get SH humidity 
sh_humidity = south['Humidity']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(south_lat, sh_humidity, marker='.', color='orange')
plt.title('Southern Hemisphere City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Regression
sh_hum_r = st.pearsonr(south_lat, sh_humidity)
sh_hum_r = sh_hum_r[0].round(2)
sh_hum_r = f"r² = {sh_hum_r}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(south_lat, sh_humidity)
sh_hum_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
sh_hum_regress = south_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(south_lat, sh_hum_regress)
plt.annotate(sh_hum_eq, (-20,45), fontsize=14, color='black')
plt.annotate(sh_hum_r, (-20,40), fontsize=14, color='black')


# Save as png 
plt.savefig('../output_data/SH_humidity.png', format='png')

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Get NH cloudiness 
nh_clouds = north['Cloudiness']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(north_lat, nh_clouds, marker='.', color='green')
plt.title('Northern Hemisphere City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Regression
nh_clouds_r = st.pearsonr(north_lat, nh_clouds)
nh_clouds_r = nh_clouds_r[0].round(2)
nh_clouds_r = f"r² = {nh_clouds_r}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(north_lat, nh_clouds)
nh_clouds_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
nh_clouds_regress = north_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(north_lat, nh_clouds_regress)
plt.annotate(nh_clouds_eq, (65,30), fontsize=15, color='darkred')
plt.annotate(nh_clouds_r, (65,20), fontsize=15, color='darkred')


# Save as png 
plt.savefig('../output_data/NH_clouds.png', format='png')

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Get SH cloudiness 
sh_clouds = south['Cloudiness']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(south_lat, sh_clouds, marker='.', color='green')
plt.title('Southern Hemisphere City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Regression
sh_clouds_r = st.pearsonr(south_lat, sh_clouds)
sh_clouds_r = sh_clouds_r[0].round(2)
sh_clouds_r = f"r² = {sh_clouds_r}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(south_lat, sh_clouds)
sh_clouds_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
sh_clouds_regress = south_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(south_lat, sh_clouds_regress)
plt.annotate(sh_clouds_eq, (-50,10), fontsize=14, color='darkred')
plt.annotate(sh_clouds_r, (-50,2), fontsize=14, color='darkred')


# Save as png 
plt.savefig('../output_data/SH_clouds.png', format='png')

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Get NH wind speed, convert to mph 
nh_wind = north['Wind Speed']
nh_wind = nh_wind * 2.237

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(north_lat, nh_wind, marker='.', color='b')
plt.title('Northern Hemisphere City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)

# Regression
nh_wind_r = st.pearsonr(north_lat, nh_wind)
nh_wind_r = nh_wind_r[0].round(2)
nh_wind_r = f"r² = {nh_wind_r}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(north_lat, nh_wind)
nh_wind_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
nh_wind_regress = north_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(north_lat, nh_wind_regress)
plt.annotate(nh_wind_eq, (10,30), fontsize=13, color='black')
plt.annotate(nh_wind_r, (10,25), fontsize=13, color='black')


# Save as png 
plt.savefig('../output_data/NH_wind.png', format='png')

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Get SH wind speed, convert to mph 
sh_wind = south['Wind Speed']
sh_wind = sh_wind * 2.237

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(south_lat, sh_wind, marker='.', color='b')
plt.title('Southern Hemisphere City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)

# Regression
sh_wind_r = st.pearsonr(south_lat, sh_wind)
sh_wind_r = sh_wind_r[0].round(2)
sh_wind_r = f"r² = {sh_wind_r}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(south_lat, sh_wind)
sh_wind_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
sh_wind_regress = south_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(south_lat, sh_wind_regress)
plt.annotate(sh_wind_eq, (-20,25), fontsize=15, color='black')
plt.annotate(sh_wind_r, (-20,23), fontsize=15, color='black')


# Save as png 
plt.savefig('../output_data/SH_wind.png', format='png')

plt.show()
