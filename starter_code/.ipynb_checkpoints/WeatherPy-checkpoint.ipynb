# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Import API Key
from api_keys import weather_api_key

# Get API url 
weather_url = "http://api.openweathermap.org/data/2.5/weather?"

# Create empty columns 
weather_df = pd.DataFrame()
weather_df['City'] = cities
weather_df['Lat'] = ""
weather_df['Long'] = ""
weather_df['Max Temp'] = ""
weather_df['Humidity'] = ""
weather_df['Cloudiness'] = ""
weather_df['Wind Speed'] = ""
weather_df['Country'] = ""
weather_df['Date'] = ""

#City name formatting 
weather_df['City'] = weather_df['City'].str.title()

weather_df
# Out:
#                  City Lat Long Max Temp Humidity Cloudiness Wind Speed  \
# 0    Illoqqortoormiut
# 1     Bambous Virieux
# 2             Chifeng
# 3           Busselton
# 4          Nikolskoye
# ..                ...  ..  ...      ...      ...        ...        ...
# 623         Concordia
# 624          Kissamos
# 625     Jinchengjiang
# 626          Babstovo
# 627          Traiguen
#
#     Country Date
# 0
# 1
# 2
# 3
# 4
# ..      ...  ...
# 623
# 624
# 625
# 626
# 627
#
# [628 rows x 9 columns]

# %%
## API calls 

print('Beginning Data Retrieval')
print('------------------------------------')

# Loop through cities and get weather. Pass if city has no data.
for index, row in weather_df.iterrows():
    
    # Get city name from dataframe 
    city = row['City']
    
    # Generate query url 
    query_url = weather_url + 'q=' + city + '&appid=' + weather_api_key
    
    try:
        # Retrieve data 
        response = requests.get(query_url).json()
        
        # Add response to column 
        print(f"Retrieving results for response {index}: {city}.")
        weather_df.loc[index, 'Lat'] = response['coord']['lat']
        weather_df.loc[index, 'Long'] = response['coord']['lon']
        weather_df.loc[index, 'Max Temp'] = response['main']['temp_max']
        weather_df.loc[index, 'Humidity'] = response['main']['humidity']
        weather_df.loc[index, 'Cloudiness'] = response['clouds']['all']
        weather_df.loc[index, 'Wind Speed'] = response['wind']['speed']
        weather_df.loc[index, 'Country'] = response['sys']['country']
        weather_df.loc[index, 'Date'] = response['dt']
    
    # Skip results with no data
    except KeyError:
        print(f'No Results for {city}... skipping')
    
    
print('------------------------------------')
print('Data Retrieval Complete')
# Out:
# Beginning Data Retrieval
# ------------------------------------
# Retrieving results for response 0: Illoqqortoormiut.
# No Results for Illoqqortoormiut... skipping
# Retrieving results for response 1: Bambous Virieux.
# Retrieving results for response 2: Chifeng.
# Retrieving results for response 3: Busselton.
# Retrieving results for response 4: Nikolskoye.
# Retrieving results for response 5: Vestmanna.
# Retrieving results for response 6: Turangi.
# Retrieving results for response 7: Mar Del Plata.
# Retrieving results for response 8: Kapaa.
# Retrieving results for response 9: Cape Town.
# Retrieving results for response 10: Rikitea.
# Retrieving results for response 11: Albany.
# Retrieving results for response 12: Victoria.
# Retrieving results for response 13: Attawapiskat.
# No Results for Attawapiskat... skipping
# Retrieving results for response 14: Talnakh.
# Retrieving results for response 15: Qaanaaq.
# Retrieving results for response 16: Waingapu.
# Retrieving results for response 17: Rawannawi.
# No Results for Rawannawi... skipping
# Retrieving results for response 18: Arraial Do Cabo.
# Retrieving results for response 19: Punta Arenas.
# Retrieving results for response 20: Barrow.
# Retrieving results for response 21: Vaini.
# Retrieving results for response 22: Atuona.
# Retrieving results for response 23: Hasaki.
# Retrieving results for response 24: Mataura.
# Retrieving results for response 25: Chipinge.
# Retrieving results for response 26: Belushya Guba.
# No Results for Belushya Guba... skipping
# Retrieving results for response 27: Wajima.
# Retrieving results for response 28: Luderitz.
# Retrieving results for response 29: Luau.
# Retrieving results for response 30: Yellowknife.
# Retrieving results for response 31: Charcas.
# Retrieving results for response 32: Eldikan.
# No Results for Eldikan... skipping
# Retrieving results for response 33: Juba.
# Retrieving results for response 34: Dunedin.
# Retrieving results for response 35: San Patricio.
# Retrieving results for response 36: Riyadh.
# Retrieving results for response 37: Mys Shmidta.
# No Results for Mys Shmidta... skipping
# Retrieving results for response 38: Layou.
# Retrieving results for response 39: Kaitangata.
# Retrieving results for response 40: Taoudenni.
# Retrieving results for response 41: Mackay.
# Retrieving results for response 42: Mount Pleasant.
# Retrieving results for response 43: Uspenka.
# Retrieving results for response 44: Kabanjahe.
# Retrieving results for response 45: Sentyabrskiy.
# No Results for Sentyabrskiy... skipping
# Retrieving results for response 46: Diamantino.
# Retrieving results for response 47: Lorengau.
# Retrieving results for response 48: Sedelnikovo.
# No Results for Sedelnikovo... skipping
# Retrieving results for response 49: Cherskiy.
# Retrieving results for response 50: Ribeira Grande.
# Retrieving results for response 51: Sabana De Torres.
# Retrieving results for response 52: Dhidhdhoo.
# Retrieving results for response 53: Dwarka.
# Retrieving results for response 54: Conde.
# Retrieving results for response 55: Boyolangu.
# Retrieving results for response 56: East London.
# Retrieving results for response 57: Samalaeulu.
# No Results for Samalaeulu... skipping
# Retrieving results for response 58: Barentsburg.
# No Results for Barentsburg... skipping
# Retrieving results for response 59: Gravdal.
# Retrieving results for response 60: Mingshui.
# Retrieving results for response 61: San Matias.
# Retrieving results for response 62: Cidreira.
# Retrieving results for response 63: Saint-Augustin.
# Retrieving results for response 64: Kodiak.
# Retrieving results for response 65: Liepaja.
# Retrieving results for response 66: Hobart.
# Retrieving results for response 67: Jamestown.
# Retrieving results for response 68: Ambilobe.
# Retrieving results for response 69: Toamasina.
# Retrieving results for response 70: Khatanga.
# Retrieving results for response 71: Soyo.
# Retrieving results for response 72: Kungurtug.
# Retrieving results for response 73: Ushuaia.
# Retrieving results for response 74: Hobyo.
# Retrieving results for response 75: Boa Vista.
# Retrieving results for response 76: Kushiro.
# Retrieving results for response 77: Vestmannaeyjar.
# Retrieving results for response 78: Zeya.
# Retrieving results for response 79: San Jose.
# Retrieving results for response 80: Katsuura.
# Retrieving results for response 81: Arlit.
# Retrieving results for response 82: Algiers.
# Retrieving results for response 83: Port Elizabeth.
# Retrieving results for response 84: Sao Francisco De Assis.
# Retrieving results for response 85: Butaritari.
# Retrieving results for response 86: Broome.
# Retrieving results for response 87: New Norfolk.
# Retrieving results for response 88: Taolanaro.
# No Results for Taolanaro... skipping
# Retrieving results for response 89: Kavaratti.
# Retrieving results for response 90: Iskateley.
# Retrieving results for response 91: Geraldton.
# Retrieving results for response 92: Sitka.
# Retrieving results for response 93: Chokurdakh.
# Retrieving results for response 94: Tiksi.
# Retrieving results for response 95: Tura.
# Retrieving results for response 96: Avarua.
# Retrieving results for response 97: Ambon.
# Retrieving results for response 98: Airai.
# Retrieving results for response 99: Urdzhar.
# No Results for Urdzhar... skipping
# Retrieving results for response 100: Lingyuan.
# Retrieving results for response 101: Ardakan.
# Retrieving results for response 102: Castro.
# Retrieving results for response 103: Umm Kaddadah.
# Retrieving results for response 104: Nguiu.
# No Results for Nguiu... skipping
# Retrieving results for response 105: Georgetown.
# Retrieving results for response 106: Lebu.
# Retrieving results for response 107: Kaman.
# Retrieving results for response 108: Takaka.
# Retrieving results for response 109: Jardim.
# Retrieving results for response 110: Port Alfred.
# Retrieving results for response 111: Avera.
# Retrieving results for response 112: Klaksvik.
# Retrieving results for response 113: Srednekolymsk.
# Retrieving results for response 114: Bowen.
# Retrieving results for response 115: Batemans Bay.
# Retrieving results for response 116: Mayumba.
# Retrieving results for response 117: Oktyabrskiy.
# Retrieving results for response 118: Husavik.
# Retrieving results for response 119: Hermanus.
# Retrieving results for response 120: Severo-Kurilsk.
# Retrieving results for response 121: Baculin.
# Retrieving results for response 122: Gat.
# Retrieving results for response 123: Sistranda.
# Retrieving results for response 124: Hami.
# Retrieving results for response 125: Yenagoa.
# Retrieving results for response 126: Tuatapere.
# Retrieving results for response 127: Cabo San Lucas.
# Retrieving results for response 128: Bethel.
# Retrieving results for response 129: San Pedro.
# Retrieving results for response 130: Saskylakh.
# Retrieving results for response 131: Torbay.
# Retrieving results for response 132: Arona.
# Retrieving results for response 133: Souillac.
# Retrieving results for response 134: Haines Junction.
# Retrieving results for response 135: Nishihara.
# Retrieving results for response 136: Alofi.
# Retrieving results for response 137: Mwanza.
# Retrieving results for response 138: Puerto Ayora.
# Retrieving results for response 139: Bartica.
# Retrieving results for response 140: Mahebourg.
# Retrieving results for response 141: Mundo Nuevo.
# Retrieving results for response 142: Chamonix-Mont-Blanc.
# Retrieving results for response 143: Tessalit.
# Retrieving results for response 144: Ylivieska.
# Retrieving results for response 145: Bengkulu.
# Retrieving results for response 146: Thompson.
# Retrieving results for response 147: Harer.
# Retrieving results for response 148: Vaitupu.
# No Results for Vaitupu... skipping
# Retrieving results for response 149: Alyangula.
# Retrieving results for response 150: Leh.
# Retrieving results for response 151: Marcona.
# No Results for Marcona... skipping
# Retrieving results for response 152: Port Hardy.
# Retrieving results for response 153: Gogrial.
# Retrieving results for response 154: Jurado.
# Retrieving results for response 155: Sur.
# Retrieving results for response 156: Komsomolskiy.
# Retrieving results for response 157: Katobu.
# Retrieving results for response 158: Maghama.
# No Results for Maghama... skipping
# Retrieving results for response 159: Chippewa Falls.
# Retrieving results for response 160: Hamilton.
# Retrieving results for response 161: Shieli.
# Retrieving results for response 162: Mangai.
# Retrieving results for response 163: Twin Falls.
# Retrieving results for response 164: Gilbues.
# Retrieving results for response 165: Amderma.
# No Results for Amderma... skipping
# Retrieving results for response 166: Meyungs.
# No Results for Meyungs... skipping
# Retrieving results for response 167: Rocha.
# Retrieving results for response 168: Vila Do Maio.
# Retrieving results for response 169: Kokopo.
# Retrieving results for response 170: Bluff.
# Retrieving results for response 171: Uppsala.
# Retrieving results for response 172: Zabol.
# Retrieving results for response 173: Vagur.
# Retrieving results for response 174: Carnarvon.
# Retrieving results for response 175: Zheleznodorozhnyy.
# Retrieving results for response 176: Woodstock.
# Retrieving results for response 177: Guerrero Negro.
# Retrieving results for response 178: Hilo.
# Retrieving results for response 179: Saint-Philippe.
# Retrieving results for response 180: Antsohihy.
# Retrieving results for response 181: Bredasdorp.
# Retrieving results for response 182: Taltal.
# Retrieving results for response 183: Sobolevo.
# Retrieving results for response 184: West Des Moines.
# Retrieving results for response 185: Ponta Do Sol.
# Retrieving results for response 186: Clyde River.
# Retrieving results for response 187: Hokitika.
# Retrieving results for response 188: Atar.
# Retrieving results for response 189: Kazanskoye.
# Retrieving results for response 190: Lompoc.
# Retrieving results for response 191: Mehamn.
# Retrieving results for response 192: Caravelas.
# Retrieving results for response 193: Geresk.
# No Results for Geresk... skipping
# Retrieving results for response 194: Yulara.
# Retrieving results for response 195: Jaguariaiva.
# Retrieving results for response 196: Mogadishu.
# Retrieving results for response 197: Constitucion.
# Retrieving results for response 198: Aklavik.
# Retrieving results for response 199: Magadan.
# Retrieving results for response 200: Iberia.
# Retrieving results for response 201: Victoria Point.
# Retrieving results for response 202: Frankfort.
# Retrieving results for response 203: Bardiyah.
# Retrieving results for response 204: Bom Jesus Do Galho.
# Retrieving results for response 205: Bundaberg.
# Retrieving results for response 206: Lazaro Cardenas.
# Retrieving results for response 207: Esperance.
# Retrieving results for response 208: Hambantota.
# Retrieving results for response 209: Yar-Sale.
# Retrieving results for response 210: Dikson.
# Retrieving results for response 211: Mende.
# Retrieving results for response 212: Rungata.
# No Results for Rungata... skipping
# Retrieving results for response 213: Asau.
# Retrieving results for response 214: Port Hope.
# Retrieving results for response 215: Manta.
# Retrieving results for response 216: Waw.
# Retrieving results for response 217: Garowe.
# Retrieving results for response 218: Aksu.
# Retrieving results for response 219: Waiouru.
# Retrieving results for response 220: San Quintin.
# Retrieving results for response 221: College.
# Retrieving results for response 222: Hithadhoo.
# Retrieving results for response 223: Ha Giang.
# Retrieving results for response 224: Tasiilaq.
# Retrieving results for response 225: Talcahuano.
# Retrieving results for response 226: Prestea.
# Retrieving results for response 227: Zhanaozen.
# Retrieving results for response 228: Malumfashi.
# Retrieving results for response 229: Buluang.
# Retrieving results for response 230: Erdenet.
# Retrieving results for response 231: Ngukurr.
# No Results for Ngukurr... skipping
# Retrieving results for response 232: Saint George.
# Retrieving results for response 233: Stephenville.
# Retrieving results for response 234: Staryy Nadym.
# Retrieving results for response 235: Carutapera.
# Retrieving results for response 236: Anadyr.
# Retrieving results for response 237: Sambava.
# Retrieving results for response 238: Chuy.
# Retrieving results for response 239: Misawa.
# Retrieving results for response 240: Naantali.
# Retrieving results for response 241: Kichera.
# Retrieving results for response 242: Den Helder.
# Retrieving results for response 243: Nanning.
# Retrieving results for response 244: Lakselv.
# Retrieving results for response 245: Naze.
# Retrieving results for response 246: Sabalgarh.
# Retrieving results for response 247: Ilulissat.
# Retrieving results for response 248: Praia.
# Retrieving results for response 249: Flin Flon.
# Retrieving results for response 250: Arman.
# Retrieving results for response 251: Sao Joao Da Barra.
# Retrieving results for response 252: Itoman.
# Retrieving results for response 253: Poum.
# Retrieving results for response 254: Rangapara.
# Retrieving results for response 255: Alakurtti.
# Retrieving results for response 256: Amapa.
# Retrieving results for response 257: Rawson.
# Retrieving results for response 258: Portland.
# Retrieving results for response 259: Salalah.
# Retrieving results for response 260: Kavieng.
# Retrieving results for response 261: Limbazi.
# Retrieving results for response 262: Lagoa.
# Retrieving results for response 263: Sao Filipe.
# Retrieving results for response 264: Sabang.
# Retrieving results for response 265: Tuktoyaktuk.
# Retrieving results for response 266: Muros.
# Retrieving results for response 267: Port-Cartier.
# Retrieving results for response 268: Xichang.
# Retrieving results for response 269: Palabuhanratu.
# No Results for Palabuhanratu... skipping
# Retrieving results for response 270: Waipawa.
# Retrieving results for response 271: Khor.
# Retrieving results for response 272: Norman Wells.
# Retrieving results for response 273: Tunduru.
# No Results for Tunduru... skipping
# Retrieving results for response 274: Cairns.
# Retrieving results for response 275: Raymondville.
# Retrieving results for response 276: Aromashevo.
# Retrieving results for response 277: Alice Springs.
# Retrieving results for response 278: Kharar.
# Retrieving results for response 279: Kovdor.
# Retrieving results for response 280: Banikoara.
# Retrieving results for response 281: Kruisfontein.
# Retrieving results for response 282: Camacha.
# Retrieving results for response 283: Roald.
# Retrieving results for response 284: Sebinkarahisar.
# Retrieving results for response 285: Malatya.
# Retrieving results for response 286: Jiujiang.
# Retrieving results for response 287: Dalbandin.
# Retrieving results for response 288: Kitimat.
# Retrieving results for response 289: Kambia.
# Retrieving results for response 290: Ixtapa.
# Retrieving results for response 291: Broken Hill.
# Retrieving results for response 292: Lata.
# Retrieving results for response 293: Sarishabari.
# Retrieving results for response 294: Cascas.
# Retrieving results for response 295: Camapua.
# Retrieving results for response 296: Nioro.
# Retrieving results for response 297: Port Blair.
# Retrieving results for response 298: Vostok.
# Retrieving results for response 299: Nemuro.
# Retrieving results for response 300: Dalry.
# Retrieving results for response 301: Pevek.
# Retrieving results for response 302: Vardo.
# Retrieving results for response 303: Miranorte.
# No Results for Miranorte... skipping
# Retrieving results for response 304: Samusu.
# No Results for Samusu... skipping
# Retrieving results for response 305: Tumannyy.
# No Results for Tumannyy... skipping
# Retrieving results for response 306: Grootfontein.
# Retrieving results for response 307: Beloha.
# Retrieving results for response 308: Jauja.
# Retrieving results for response 309: Najran.
# Retrieving results for response 310: Kathu.
# Retrieving results for response 311: Aktau.
# Retrieving results for response 312: Iralaya.
# Retrieving results for response 313: Ketchikan.
# Retrieving results for response 314: Kahului.
# Retrieving results for response 315: Phnum Penh.
# No Results for Phnum Penh... skipping
# Retrieving results for response 316: Irbil.
# Retrieving results for response 317: Natal.
# Retrieving results for response 318: Leningradskiy.
# Retrieving results for response 319: Louisbourg.
# No Results for Louisbourg... skipping
# Retrieving results for response 320: Strezhevoy.
# Retrieving results for response 321: Sheridan.
# Retrieving results for response 322: Pisco.
# Retrieving results for response 323: Ozernovskiy.
# Retrieving results for response 324: Prince Rupert.
# Retrieving results for response 325: Kalmunai.
# Retrieving results for response 326: Bull Savanna.
# Retrieving results for response 327: Bilma.
# Retrieving results for response 328: Tautira.
# Retrieving results for response 329: Shebalino.
# Retrieving results for response 330: Kodinar.
# Retrieving results for response 331: Upernavik.
# Retrieving results for response 332: Bolshegrivskoye.
# No Results for Bolshegrivskoye... skipping
# Retrieving results for response 333: Boyuibe.
# Retrieving results for response 334: Necochea.
# Retrieving results for response 335: Brufut.
# Retrieving results for response 336: Namie.
# Retrieving results for response 337: Cam Ranh.
# Retrieving results for response 338: Koumac.
# Retrieving results for response 339: Kamenskoye.
# No Results for Kamenskoye... skipping
# Retrieving results for response 340: Pedernales.
# Retrieving results for response 341: Tambun.
# Retrieving results for response 342: Longyearbyen.
# Retrieving results for response 343: Nuuk.
# Retrieving results for response 344: Nalut.
# Retrieving results for response 345: Hualmay.
# Retrieving results for response 346: Moba.
# Retrieving results for response 347: Te Anau.
# Retrieving results for response 348: Angoche.
# Retrieving results for response 349: Howard Springs.
# Retrieving results for response 350: Isangel.
# Retrieving results for response 351: Kultuk.
# Retrieving results for response 352: Golubitskaya.
# Retrieving results for response 353: Sedalia.
# Retrieving results for response 354: Sabha.
# Retrieving results for response 355: Ponta Delgada.
# Retrieving results for response 356: Kozhevnikovo.
# Retrieving results for response 357: Emerald.
# Retrieving results for response 358: La Bruyere.
# Retrieving results for response 359: Bathsheba.
# Retrieving results for response 360: Tzimol.
# Retrieving results for response 361: Narsaq.
# Retrieving results for response 362: Verkh-Usugli.
# Retrieving results for response 363: Beyneu.
# Retrieving results for response 364: Georgiyevka.
# Retrieving results for response 365: Makakilo City.
# Retrieving results for response 366: Shibetsu.
# Retrieving results for response 367: Gidam.
# Retrieving results for response 368: Saint-Joseph.
# Retrieving results for response 369: San Juan.
# Retrieving results for response 370: Khormuj.
# No Results for Khormuj... skipping
# Retrieving results for response 371: Shingu.
# Retrieving results for response 372: Ossora.
# Retrieving results for response 373: Jasidih.
# Retrieving results for response 374: Acari.
# Retrieving results for response 375: Adrar.
# Retrieving results for response 376: Beringovskiy.
# Retrieving results for response 377: Maldonado.
# Retrieving results for response 378: Sinnamary.
# Retrieving results for response 379: Iquitos.
# Retrieving results for response 380: Sisimiut.
# Retrieving results for response 381: Umm Lajj.
# Retrieving results for response 382: Vanavara.
# Retrieving results for response 383: Kamenka.
# Retrieving results for response 384: Hay River.
# Retrieving results for response 385: Libano.
# Retrieving results for response 386: Rafsanjan.
# Retrieving results for response 387: Sangar.
# Retrieving results for response 388: Bad Salzungen.
# Retrieving results for response 389: Glace Bay.
# Retrieving results for response 390: Ancud.
# Retrieving results for response 391: Denpasar.
# Retrieving results for response 392: Surt.
# Retrieving results for response 393: Jambi.
# Retrieving results for response 394: Jacareacanga.
# Retrieving results for response 395: Bairiki.
# Retrieving results for response 396: Lanzhou.
# Retrieving results for response 397: Bodden Town.
# Retrieving results for response 398: Hongjiang.
# Retrieving results for response 399: Kendari.
# Retrieving results for response 400: Finschhafen.
# Retrieving results for response 401: Galveston.
# Retrieving results for response 402: Almeirim.
# Retrieving results for response 403: Dodge City.
# Retrieving results for response 404: Nizhneyansk.
# No Results for Nizhneyansk... skipping
# Retrieving results for response 405: Lincoln.
# Retrieving results for response 406: Othonoi.
# No Results for Othonoi... skipping
# Retrieving results for response 407: Antofagasta.
# Retrieving results for response 408: Hihifo.
# No Results for Hihifo... skipping
# Retrieving results for response 409: Padang.
# Retrieving results for response 410: Belaya Gora.
# Retrieving results for response 411: Mecca.
# Retrieving results for response 412: Mezen.
# Retrieving results for response 413: Qaqortoq.
# Retrieving results for response 414: Rock Sound.
# Retrieving results for response 415: Coruripe.
# Retrieving results for response 416: Poiana Marului.
# Retrieving results for response 417: Lewistown.
# Retrieving results for response 418: Worland.
# Retrieving results for response 419: Jumla.
# Retrieving results for response 420: Desaguadero.
# Retrieving results for response 421: Kieta.
# Retrieving results for response 422: Havoysund.
# Retrieving results for response 423: Whitehorse.
# Retrieving results for response 424: Chicama.
# Retrieving results for response 425: Faanui.
# Retrieving results for response 426: Gizo.
# Retrieving results for response 427: Karratha.
# Retrieving results for response 428: Bukama.
# Retrieving results for response 429: Kununurra.
# Retrieving results for response 430: Am Timan.
# Retrieving results for response 431: Liwale.
# Retrieving results for response 432: Marsh Harbour.
# Retrieving results for response 433: Ust-Tsilma.
# Retrieving results for response 434: Kemlya.
# Retrieving results for response 435: Bandarbeyla.
# Retrieving results for response 436: Russell.
# Retrieving results for response 437: Lucapa.
# Retrieving results for response 438: Dublin.
# Retrieving results for response 439: Fiche.
# Retrieving results for response 440: Sibolga.
# Retrieving results for response 441: Tomatlan.
# Retrieving results for response 442: Omboue.
# Retrieving results for response 443: Rybnaya Sloboda.
# Retrieving results for response 444: North Bend.
# Retrieving results for response 445: Hojai.
# Retrieving results for response 446: Ippy.
# Retrieving results for response 447: Yangcun.
# Retrieving results for response 448: Awbari.
# Retrieving results for response 449: Caceres.
# Retrieving results for response 450: Pangnirtung.
# Retrieving results for response 451: Ende.
# Retrieving results for response 452: Lambarene.
# Retrieving results for response 453: Nzega.
# Retrieving results for response 454: San Ramon.
# Retrieving results for response 455: Chapais.
# Retrieving results for response 456: Igarka.
# Retrieving results for response 457: Calbuco.
# Retrieving results for response 458: Nampula.
# Retrieving results for response 459: Lolua.
# No Results for Lolua... skipping
# Retrieving results for response 460: Fairbanks.
# Retrieving results for response 461: Lisakovsk.
# Retrieving results for response 462: Sao Miguel Do Araguaia.
# Retrieving results for response 463: Concepcion.
# Retrieving results for response 464: Sao Jose Da Coroa Grande.
# Retrieving results for response 465: Mao.
# Retrieving results for response 466: Vredefort.
# Retrieving results for response 467: Corpus Christi.
# Retrieving results for response 468: Nanakuli.
# Retrieving results for response 469: Henties Bay.
# Retrieving results for response 470: Aljezur.
# Retrieving results for response 471: La Fria.
# Retrieving results for response 472: Verkhniy Avzyan.
# Retrieving results for response 473: Bilgoraj.
# Retrieving results for response 474: Maceio.
# Retrieving results for response 475: Hanko.
# Retrieving results for response 476: Karoi.
# Retrieving results for response 477: Biak.
# Retrieving results for response 478: Margate.
# Retrieving results for response 479: Diego De Almagro.
# Retrieving results for response 480: Saint-Leu.
# Retrieving results for response 481: Kampene.
# Retrieving results for response 482: Auburn.
# Retrieving results for response 483: Hakkari.
# Retrieving results for response 484: Eucaliptus.
# Retrieving results for response 485: Ayan.
# Retrieving results for response 486: Dargaville.
# Retrieving results for response 487: Mount Gambier.
# Retrieving results for response 488: Tual.
# Retrieving results for response 489: Skibbereen.
# Retrieving results for response 490: Okato.
# Retrieving results for response 491: Westport.
# Retrieving results for response 492: Liverpool.
# Retrieving results for response 493: Beaverlodge.
# Retrieving results for response 494: Ngunguru.
# Retrieving results for response 495: Sumenep.
# Retrieving results for response 496: Desur.
# Retrieving results for response 497: Kutoarjo.
# Retrieving results for response 498: Saleaula.
# No Results for Saleaula... skipping
# Retrieving results for response 499: Terrace Bay.
# Retrieving results for response 500: Vila Velha.
# Retrieving results for response 501: Rocky Mountain House.
# Retrieving results for response 502: Kemijarvi.
# Retrieving results for response 503: Hohhot.
# Retrieving results for response 504: Aleksandrov Gay.
# Retrieving results for response 505: Jahrom.
# No Results for Jahrom... skipping
# Retrieving results for response 506: Dingle.
# Retrieving results for response 507: Sibiti.
# Retrieving results for response 508: Paamiut.
# Retrieving results for response 509: Presidencia Roque Saenz Pena.
# Retrieving results for response 510: Marang.
# Retrieving results for response 511: Grindavik.
# Retrieving results for response 512: Sataua.
# No Results for Sataua... skipping
# Retrieving results for response 513: Tapaua.
# No Results for Tapaua... skipping
# Retrieving results for response 514: Batsfjord.
# Retrieving results for response 515: Concepcion Del Oro.
# Retrieving results for response 516: Salym.
# Retrieving results for response 517: Severnyy.
# Retrieving results for response 518: Port Lincoln.
# Retrieving results for response 519: Veraval.
# Retrieving results for response 520: Saint Anthony.
# Retrieving results for response 521: Charters Towers.
# Retrieving results for response 522: Sakaiminato.
# Retrieving results for response 523: Inuvik.
# Retrieving results for response 524: Mountain Home.
# Retrieving results for response 525: Codrington.
# Retrieving results for response 526: Panguna.
# Retrieving results for response 527: Half Moon Bay.
# Retrieving results for response 528: Matara.
# Retrieving results for response 529: Hillsboro.
# Retrieving results for response 530: Ngaoundere.
# Retrieving results for response 531: Galchino.
# No Results for Galchino... skipping
# Retrieving results for response 532: Palatka.
# Retrieving results for response 533: San Vicente.
# Retrieving results for response 534: Neiafu.
# Retrieving results for response 535: Ridgecrest.
# Retrieving results for response 536: Atasu.
# Retrieving results for response 537: Jiexiu.
# Retrieving results for response 538: Kidsgrove.
# Retrieving results for response 539: Mafinga.
# Retrieving results for response 540: Provideniya.
# Retrieving results for response 541: Hovd.
# Retrieving results for response 542: Maturin.
# Retrieving results for response 543: Korla.
# Retrieving results for response 544: Karakol.
# Retrieving results for response 545: Jurbarkas.
# Retrieving results for response 546: Akyab.
# Retrieving results for response 547: Axim.
# Retrieving results for response 548: Bemidji.
# Retrieving results for response 549: Rio Grande.
# Retrieving results for response 550: Ust-Kamchatsk.
# No Results for Ust-Kamchatsk... skipping
# Retrieving results for response 551: Jalu.
# Retrieving results for response 552: Rio Gallegos.
# Retrieving results for response 553: Sampit.
# Retrieving results for response 554: Lensk.
# Retrieving results for response 555: Misratah.
# Retrieving results for response 556: Sidi Ali.
# Retrieving results for response 557: Dolbeau.
# No Results for Dolbeau... skipping
# Retrieving results for response 558: Salinopolis.
# Retrieving results for response 559: Matagami.
# Retrieving results for response 560: Ambovombe.
# Retrieving results for response 561: Ugoofaaru.
# Retrieving results for response 562: Quatre Cocos.
# Retrieving results for response 563: San Rafael.
# Retrieving results for response 564: Bokoro.
# Retrieving results for response 565: Lerwick.
# Retrieving results for response 566: Penzance.
# Retrieving results for response 567: Morondava.
# Retrieving results for response 568: Svetlaya.
# Retrieving results for response 569: Miraflores.
# Retrieving results for response 570: Inzer.
# Retrieving results for response 571: Peniche.
# Retrieving results for response 572: Healdsburg.
# Retrieving results for response 573: Impfondo.
# Retrieving results for response 574: Gazojak.
# Retrieving results for response 575: Sinop.
# Retrieving results for response 576: Arkadak.
# Retrieving results for response 577: Chuncheng.
# Retrieving results for response 578: Solsvik.
# No Results for Solsvik... skipping
# Retrieving results for response 579: Mayo.
# Retrieving results for response 580: Camacari.
# Retrieving results for response 581: Chakan.
# Retrieving results for response 582: Warqla.
# No Results for Warqla... skipping
# Retrieving results for response 583: Chara.
# Retrieving results for response 584: Olinda.
# Retrieving results for response 585: Senanga.
# Retrieving results for response 586: Evensk.
# Retrieving results for response 587: Terme.
# Retrieving results for response 588: Analipsis.
# Retrieving results for response 589: Bolungarvik.
# No Results for Bolungarvik... skipping
# Retrieving results for response 590: Emirdag.
# Retrieving results for response 591: Prabumulih.
# Retrieving results for response 592: Davidson.
# Retrieving results for response 593: Mahajanga.
# Retrieving results for response 594: Galesong.
# Retrieving results for response 595: Beaupre.
# Retrieving results for response 596: Ratnagiri.
# Retrieving results for response 597: Namatanai.
# Retrieving results for response 598: Bilibino.
# Retrieving results for response 599: The Pas.
# Retrieving results for response 600: Cabedelo.
# Retrieving results for response 601: Zhezkazgan.
# Retrieving results for response 602: Mount Isa.
# Retrieving results for response 603: San Cristobal.
# Retrieving results for response 604: Bosaso.
# Retrieving results for response 605: Sorland.
# Retrieving results for response 606: Deputatskiy.
# Retrieving results for response 607: Flinders.
# Retrieving results for response 608: Nanortalik.
# Retrieving results for response 609: Aykhal.
# Retrieving results for response 610: Siyabuswa.
# Retrieving results for response 611: Labuhan.
# Retrieving results for response 612: Shaunavon.
# Retrieving results for response 613: Namibe.
# Retrieving results for response 614: Batagay.
# Retrieving results for response 615: Lavrentiya.
# Retrieving results for response 616: Mahalingpur.
# Retrieving results for response 617: Galle.
# Retrieving results for response 618: Mandera.
# Retrieving results for response 619: Iqaluit.
# Retrieving results for response 620: Maues.
# Retrieving results for response 621: Kiama.
# Retrieving results for response 622: Baruun-Urt.
# Retrieving results for response 623: Concordia.
# Retrieving results for response 624: Kissamos.
# Retrieving results for response 625: Jinchengjiang.
# No Results for Jinchengjiang... skipping
# Retrieving results for response 626: Babstovo.
# Retrieving results for response 627: Traiguen.
# ------------------------------------
# Data Retrieval Complete

# %%
# Export as csv file 
weather_df.to_csv(output_data_file)

# Display dataframe 
weather_df
# Out:
#                  City      Lat     Long Max Temp Humidity Cloudiness  \
# 0    Illoqqortoormiut
# 1     Bambous Virieux -20.3428  57.7575   302.04       65         40
# 2             Chifeng  42.2683  118.964   273.58       89         47
# 3           Busselton   -33.65  115.333   297.04       42          1
# 4          Nikolskoye  59.7035  30.7861   258.71       85         20
# ..                ...      ...      ...      ...      ...        ...
# 623         Concordia  -31.393 -58.0209   292.04       83          0
# 624          Kissamos  35.4939  23.6569   285.15       94         20
# 625     Jinchengjiang
# 626          Babstovo  48.1167  132.483    254.7       85         90
# 627          Traiguen   -38.25 -72.6833   290.88       57          0
#
#     Wind Speed Country        Date
# 0
# 1         5.14      MU  1612499367
# 2         4.93      CN  1612499367
# 3         1.34      AU  1612499367
# 4            4      RU  1612499367
# ..         ...     ...         ...
# 623        1.6      AR  1612499474
# 624       3.09      GR  1612499474
# 625
# 626       2.46      RU  1612499475
# 627       0.24      CL  1612499475
#
# [628 rows x 9 columns]

# %%
# Convert data types to numerical and get statistical summary 
numerical_df = weather_df[['Lat', 'Long', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date']]
numerical_df = numerical_df.apply(pd.to_numeric)
numerical_df.describe().round(2)
# Out:
#           Lat    Long  Max Temp  Humidity  Cloudiness  Wind Speed  \
# count  582.00  582.00    582.00    582.00      582.00      582.00
# mean    19.37   19.43    283.60     72.75       53.63        3.59
# std     33.47   91.10     17.10     19.61       38.37        2.46
# min    -54.80 -175.20    231.15     17.00        0.00        0.09
# 25%     -8.11  -59.85    274.15     64.00       14.25        1.76
# 50%     22.75   25.19    288.76     77.00       63.00        3.09
# 75%     47.62   98.71    297.15     88.00       90.00        4.68
# max     78.22  179.32    309.15    100.00      100.00       13.93
#
#                Date
# count  5.820000e+02
# mean   1.612499e+09
# std    1.496400e+02
# min    1.612499e+09
# 25%    1.612499e+09
# 50%    1.612499e+09
# 75%    1.612499e+09
# max    1.612499e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100% and drop by index if there are any outliers.

high_humid = numerical_df.loc[numerical_df['Humidity'] > 100].index

if len(high_humid) == 0:
    print('No cities have a humidity > 100%')
if len(high_humid) > 0:
    weather_df = weather_df.drop(high_humid)
    display(weather_df)
# Out:
# No cities have a humidity > 100%

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Get X and Y values
latitude = numerical_df['Lat']
temp = numerical_df['Max Temp']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(latitude, temp, marker='.', color='red')
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (K)')
plt.grid(True)

# Save as png 
plt.savefig('../output_data/lat_temp.png', format='png')

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Get humidity data
humidity = numerical_df['Humidity']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(latitude, humidity, marker='.', color='orange')
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Save as png 
plt.savefig('../output_data/lat_humid.png', format='png')

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Get cloudiness data
clouds = numerical_df['Cloudiness']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(latitude, clouds, marker='.', color='green')
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Save as png 
plt.savefig('../output_data/lat_cloud.png', format='png')

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Get wind speed data
wind = numerical_df['Wind Speed']

# Plot 
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(latitude, temp, marker='.', color='b')
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid(True)

# Save as png 
plt.savefig('../output_data/lat_wind.png', format='png')

plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Select Northern Hemisphere data
north = numerical_df.loc[numerical_df['Lat'] > 0]

# Get NH Max temp and latitude and convert to farenheit
north_temp = north['Max Temp']
north_temp_f = (north_temp - 273.15) * 9/5 + 32
north_lat = north['Lat']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(north_lat, north_temp_f, marker='.', color='red')
plt.title('Northern Hemisphere City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(True)

# Regression
r_sq = st.pearsonr(north_lat, north_temp_f)
r_sq = r_sq[0].round(2)
NH_temp_r = f"r² = {r_sq}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(north_lat, north_temp_f)
north_temp_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
regression = north_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(north_lat, regression)
plt.annotate(north_temp_eq, (50,80), fontsize=12, color='black')
plt.annotate(NH_temp_r, (50,70), fontsize=12, color='black')


# Save as png 
plt.savefig('../output_data/NH_temp.png', format='png')

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Select Northern Hemisphere data
south = numerical_df.loc[numerical_df['Lat'] < 0]

# Get NH Max temp and latitude and convert to F
south_temp = south['Max Temp']
south_temp = (south_temp - 273.15) * 9/5 + 32
south_lat = south['Lat']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(south_lat, south_temp, marker='.', color='red')
plt.title('Southern Hemisphere City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(True)

# Regression
s_r_sq = st.pearsonr(south_lat, south_temp)
s_r_sq = s_r_sq[0].round(2)
sh_temp_r = f"r² = {s_r_sq}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(south_lat, south_temp)
south_temp_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
sh_regression = south_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(south_lat, sh_regression)
plt.annotate(south_temp_eq, (-50,90), fontsize=12, color='black')
plt.annotate(sh_temp_r, (-50,85), fontsize=12, color='black')


# Save as png 
plt.savefig('../output_data/SH_temp.png', format='png')

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Get NH humidity 
nh_humidity = north['Humidity']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(north_lat, nh_humidity, marker='.', color='orange')
plt.title('Northern Hemisphere City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Regression
nh_hum_r = st.pearsonr(north_lat, nh_humidity)
nh_hum_r = nh_hum_r[0].round(2)
nh_hum_r = f"r² = {nh_hum_r}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(north_lat, nh_humidity)
nh_hum_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
nh_hum_regress = north_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(north_lat, nh_hum_regress)
plt.annotate(nh_hum_eq, (50,40), fontsize=14, color='black')
plt.annotate(nh_hum_r, (50,35), fontsize=14, color='black')


# Save as png 
plt.savefig('../output_data/NH_humidity.png', format='png')

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Get SH humidity 
sh_humidity = south['Humidity']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(south_lat, sh_humidity, marker='.', color='orange')
plt.title('Southern Hemisphere City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Regression
sh_hum_r = st.pearsonr(south_lat, sh_humidity)
sh_hum_r = sh_hum_r[0].round(2)
sh_hum_r = f"r² = {sh_hum_r}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(south_lat, sh_humidity)
sh_hum_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
sh_hum_regress = south_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(south_lat, sh_hum_regress)
plt.annotate(sh_hum_eq, (-20,45), fontsize=14, color='black')
plt.annotate(sh_hum_r, (-20,40), fontsize=14, color='black')


# Save as png 
plt.savefig('../output_data/SH_humidity.png', format='png')

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Get NH cloudiness 
nh_clouds = north['Cloudiness']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(north_lat, nh_clouds, marker='.', color='green')
plt.title('Northern Hemisphere City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Regression
nh_clouds_r = st.pearsonr(north_lat, nh_clouds)
nh_clouds_r = nh_clouds_r[0].round(2)
nh_clouds_r = f"r² = {nh_clouds_r}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(north_lat, nh_clouds)
nh_clouds_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
nh_clouds_regress = north_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(north_lat, nh_clouds_regress)
plt.annotate(nh_clouds_eq, (65,30), fontsize=15, color='darkred')
plt.annotate(nh_clouds_r, (65,20), fontsize=15, color='darkred')


# Save as png 
plt.savefig('../output_data/NH_clouds.png', format='png')

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Get SH cloudiness 
sh_clouds = south['Cloudiness']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(south_lat, sh_clouds, marker='.', color='green')
plt.title('Southern Hemisphere City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Regression
sh_clouds_r = st.pearsonr(south_lat, sh_clouds)
sh_clouds_r = sh_clouds_r[0].round(2)
sh_clouds_r = f"r² = {sh_clouds_r}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(south_lat, sh_clouds)
sh_clouds_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
sh_clouds_regress = south_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(south_lat, sh_clouds_regress)
plt.annotate(sh_clouds_eq, (-50,10), fontsize=14, color='darkred')
plt.annotate(sh_clouds_r, (-50,2), fontsize=14, color='darkred')


# Save as png 
plt.savefig('../output_data/SH_clouds.png', format='png')

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Get NH wind speed, convert to mph 
nh_wind = north['Wind Speed']
nh_wind = nh_wind * 2.237

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(north_lat, nh_wind, marker='.', color='b')
plt.title('Northern Hemisphere City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)

# Regression
nh_wind_r = st.pearsonr(north_lat, nh_wind)
nh_wind_r = nh_wind_r[0].round(2)
nh_wind_r = f"r² = {nh_wind_r}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(north_lat, nh_wind)
nh_wind_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
nh_wind_regress = north_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(north_lat, nh_wind_regress)
plt.annotate(nh_wind_eq, (10,30), fontsize=13, color='black')
plt.annotate(nh_wind_r, (10,25), fontsize=13, color='black')


# Save as png 
plt.savefig('../output_data/NH_wind.png', format='png')

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Get SH wind speed, convert to mph 
sh_wind = south['Wind Speed']
sh_wind = sh_wind * 2.237

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(south_lat, sh_wind, marker='.', color='b')
plt.title('Southern Hemisphere City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)

# Regression
sh_wind_r = st.pearsonr(south_lat, sh_wind)
sh_wind_r = sh_wind_r[0].round(2)
sh_wind_r = f"r² = {sh_wind_r}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(south_lat, sh_wind)
sh_wind_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
sh_wind_regress = south_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(south_lat, sh_wind_regress)
plt.annotate(sh_wind_eq, (-20,25), fontsize=15, color='black')
plt.annotate(sh_wind_r, (-20,23), fontsize=15, color='black')


# Save as png 
plt.savefig('../output_data/SH_wind.png', format='png')

plt.show()
