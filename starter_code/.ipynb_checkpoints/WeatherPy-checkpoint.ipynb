# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Import API Key
from api_keys import weather_api_key

# Get API url 
weather_url = "http://api.openweathermap.org/data/2.5/weather?"

# Create empty columns 
weather_df = pd.DataFrame()
weather_df['City'] = cities
weather_df['Lat'] = ""
weather_df['Long'] = ""
weather_df['Max Temp'] = ""
weather_df['Humidity'] = ""
weather_df['Cloudiness'] = ""
weather_df['Wind Speed'] = ""
weather_df['Country'] = ""
weather_df['Date'] = ""

#City name formatting 
weather_df['City'] = weather_df['City'].str.title()

weather_df
# Out:
#             City Lat Long Max Temp Humidity Cloudiness Wind Speed Country Date
# 0    East London
# 1         Viedma
# 2         Atuona
# 3      Taolanaro
# 4           Lebu
# ..           ...  ..  ...      ...      ...        ...        ...     ...  ...
# 607     Qaqortoq
# 608       Urucui
# 609    Bonavista
# 610   Diamantino
# 611      Mareeba
#
# [612 rows x 9 columns]

# %%
## API calls 

print('Beginning Data Retrieval')
print('------------------------------------')

# Loop through cities and get weather. Pass if city has no data.
for index, row in weather_df.iterrows():
    
    # Get city name from dataframe 
    city = row['City']
    
    # Generate query url 
    query_url = weather_url + 'q=' + city + '&appid=' + weather_api_key
    
    try:
        # Retrieve data 
        response = requests.get(query_url).json()
        
        # Add response to column 
        print(f"Retrieving results for response {index}: {city}.")
        weather_df.loc[index, 'Lat'] = response['coord']['lat']
        weather_df.loc[index, 'Long'] = response['coord']['lon']
        weather_df.loc[index, 'Max Temp'] = response['main']['temp_max']
        weather_df.loc[index, 'Humidity'] = response['main']['humidity']
        weather_df.loc[index, 'Cloudiness'] = response['clouds']['all']
        weather_df.loc[index, 'Wind Speed'] = response['wind']['speed']
        weather_df.loc[index, 'Country'] = response['sys']['country']
        weather_df.loc[index, 'Date'] = response['dt']
    
    # Skip results with no data
    except KeyError:
        print(f'No Results for {city}... skipping')
    
    
print('------------------------------------')
print('Data Retrieval Complete')
# Out:
# Beginning Data Retrieval
# ------------------------------------
# Retrieving results for response 0: east london.
# Retrieving results for response 1: viedma.
# Retrieving results for response 2: atuona.
# Retrieving results for response 3: taolanaro.
# No Results for taolanaro... skipping
# Retrieving results for response 4: lebu.
# Retrieving results for response 5: klimovo.
# Retrieving results for response 6: kodiak.
# Retrieving results for response 7: concordia.
# Retrieving results for response 8: kapaa.
# Retrieving results for response 9: qaanaaq.
# Retrieving results for response 10: mataura.
# Retrieving results for response 11: bathsheba.
# Retrieving results for response 12: bluff.
# Retrieving results for response 13: broome.
# Retrieving results for response 14: tuktoyaktuk.
# Retrieving results for response 15: clyde river.
# Retrieving results for response 16: hamilton.
# Retrieving results for response 17: nouadhibou.
# Retrieving results for response 18: rocha.
# Retrieving results for response 19: mentok.
# No Results for mentok... skipping
# Retrieving results for response 20: ushuaia.
# Retrieving results for response 21: hobart.
# Retrieving results for response 22: avarua.
# Retrieving results for response 23: vernon.
# Retrieving results for response 24: victoria.
# Retrieving results for response 25: rikitea.
# Retrieving results for response 26: puerto ayora.
# Retrieving results for response 27: dikson.
# Retrieving results for response 28: bredasdorp.
# Retrieving results for response 29: arraial do cabo.
# Retrieving results for response 30: college.
# Retrieving results for response 31: hermanus.
# Retrieving results for response 32: margate.
# Retrieving results for response 33: barrow.
# Retrieving results for response 34: solnechnyy.
# Retrieving results for response 35: siocon.
# Retrieving results for response 36: punta arenas.
# Retrieving results for response 37: inhambane.
# Retrieving results for response 38: barentsburg.
# No Results for barentsburg... skipping
# Retrieving results for response 39: gazni.
# No Results for gazni... skipping
# Retrieving results for response 40: avera.
# Retrieving results for response 41: busselton.
# Retrieving results for response 42: provideniya.
# Retrieving results for response 43: butaritari.
# Retrieving results for response 44: comodoro rivadavia.
# Retrieving results for response 45: cabo san lucas.
# Retrieving results for response 46: chokurdakh.
# Retrieving results for response 47: ngukurr.
# No Results for ngukurr... skipping
# Retrieving results for response 48: north bend.
# Retrieving results for response 49: grandview.
# Retrieving results for response 50: lata.
# Retrieving results for response 51: nikolskoye.
# Retrieving results for response 52: guerrero negro.
# Retrieving results for response 53: illoqqortoormiut.
# No Results for illoqqortoormiut... skipping
# Retrieving results for response 54: camacha.
# Retrieving results for response 55: airai.
# Retrieving results for response 56: rio gallegos.
# Retrieving results for response 57: tarudant.
# No Results for tarudant... skipping
# Retrieving results for response 58: new norfolk.
# Retrieving results for response 59: luderitz.
# Retrieving results for response 60: eirunepe.
# Retrieving results for response 61: samarai.
# Retrieving results for response 62: hilo.
# Retrieving results for response 63: severo-kurilsk.
# Retrieving results for response 64: port keats.
# Retrieving results for response 65: acarau.
# Retrieving results for response 66: touros.
# Retrieving results for response 67: nhulunbuy.
# Retrieving results for response 68: upernavik.
# Retrieving results for response 69: kuryk.
# Retrieving results for response 70: esperance.
# Retrieving results for response 71: saskylakh.
# Retrieving results for response 72: los llanos de aridane.
# Retrieving results for response 73: souillac.
# Retrieving results for response 74: khatanga.
# Retrieving results for response 75: namibe.
# Retrieving results for response 76: pulsano.
# Retrieving results for response 77: cradock.
# Retrieving results for response 78: kapit.
# Retrieving results for response 79: rockland.
# Retrieving results for response 80: sao filipe.
# Retrieving results for response 81: laguna.
# Retrieving results for response 82: medak.
# Retrieving results for response 83: fort saint john.
# No Results for fort saint john... skipping
# Retrieving results for response 84: manuk mangkaw.
# Retrieving results for response 85: seoul.
# Retrieving results for response 86: priiskovyy.
# Retrieving results for response 87: peniche.
# Retrieving results for response 88: moba.
# Retrieving results for response 89: saint-philippe.
# Retrieving results for response 90: kudahuvadhoo.
# Retrieving results for response 91: bambous virieux.
# Retrieving results for response 92: carnarvon.
# Retrieving results for response 93: vaini.
# Retrieving results for response 94: kurumkan.
# Retrieving results for response 95: emerald.
# Retrieving results for response 96: petropavlovsk-kamchatskiy.
# Retrieving results for response 97: vaitupu.
# No Results for vaitupu... skipping
# Retrieving results for response 98: kimbe.
# Retrieving results for response 99: itacoatiara.
# Retrieving results for response 100: kununurra.
# Retrieving results for response 101: geraldton.
# Retrieving results for response 102: kedrovyy.
# Retrieving results for response 103: codrington.
# Retrieving results for response 104: berlevag.
# Retrieving results for response 105: poplar bluff.
# Retrieving results for response 106: port alfred.
# Retrieving results for response 107: jamestown.
# Retrieving results for response 108: teahupoo.
# Retrieving results for response 109: sitka.
# Retrieving results for response 110: boa vista.
# Retrieving results for response 111: buarcos.
# Retrieving results for response 112: port elizabeth.
# Retrieving results for response 113: ponta do sol.
# Retrieving results for response 114: gamba.
# Retrieving results for response 115: saint-augustin.
# Retrieving results for response 116: saint george.
# Retrieving results for response 117: awjilah.
# Retrieving results for response 118: sabang.
# Retrieving results for response 119: kahului.
# Retrieving results for response 120: vao.
# Retrieving results for response 121: broken hill.
# Retrieving results for response 122: norman wells.
# Retrieving results for response 123: marathon.
# Retrieving results for response 124: tiksi.
# Retrieving results for response 125: tuatapere.
# Retrieving results for response 126: garango.
# Retrieving results for response 127: san patricio.
# Retrieving results for response 128: gigmoto.
# Retrieving results for response 129: bundaberg.
# Retrieving results for response 130: port-cartier.
# Retrieving results for response 131: trofors.
# Retrieving results for response 132: ribeira grande.
# Retrieving results for response 133: san ramon.
# Retrieving results for response 134: vostok.
# Retrieving results for response 135: belushya guba.
# No Results for belushya guba... skipping
# Retrieving results for response 136: paamiut.
# Retrieving results for response 137: eyl.
# Retrieving results for response 138: gorontalo.
# Retrieving results for response 139: aracati.
# Retrieving results for response 140: pangnirtung.
# Retrieving results for response 141: albany.
# Retrieving results for response 142: hithadhoo.
# Retrieving results for response 143: kaitangata.
# Retrieving results for response 144: namatanai.
# Retrieving results for response 145: bilibino.
# Retrieving results for response 146: campobello di mazara.
# Retrieving results for response 147: saldanha.
# Retrieving results for response 148: sumbe.
# Retrieving results for response 149: macaboboni.
# No Results for macaboboni... skipping
# Retrieving results for response 150: altay.
# Retrieving results for response 151: kenai.
# Retrieving results for response 152: tasiilaq.
# Retrieving results for response 153: tasbuget.
# No Results for tasbuget... skipping
# Retrieving results for response 154: havre-saint-pierre.
# Retrieving results for response 155: bur gabo.
# No Results for bur gabo... skipping
# Retrieving results for response 156: talnakh.
# Retrieving results for response 157: fairbanks.
# Retrieving results for response 158: narsaq.
# Retrieving results for response 159: kesan.
# Retrieving results for response 160: kloulklubed.
# Retrieving results for response 161: ruteng.
# Retrieving results for response 162: faanui.
# Retrieving results for response 163: itarema.
# Retrieving results for response 164: kashi.
# Retrieving results for response 165: nizhneyansk.
# No Results for nizhneyansk... skipping
# Retrieving results for response 166: dunedin.
# Retrieving results for response 167: rungata.
# No Results for rungata... skipping
# Retrieving results for response 168: sale.
# Retrieving results for response 169: mount gambier.
# Retrieving results for response 170: gat.
# Retrieving results for response 171: bethel.
# Retrieving results for response 172: pevek.
# Retrieving results for response 173: chenghai.
# Retrieving results for response 174: toliary.
# No Results for toliary... skipping
# Retrieving results for response 175: tazovskiy.
# Retrieving results for response 176: cape town.
# Retrieving results for response 177: lincoln.
# Retrieving results for response 178: pokrovsk-uralskiy.
# No Results for pokrovsk-uralskiy... skipping
# Retrieving results for response 179: thompson.
# Retrieving results for response 180: lavrentiya.
# Retrieving results for response 181: kaeo.
# Retrieving results for response 182: mahebourg.
# Retrieving results for response 183: tura.
# Retrieving results for response 184: hambantota.
# Retrieving results for response 185: havoysund.
# Retrieving results for response 186: karauzyak.
# No Results for karauzyak... skipping
# Retrieving results for response 187: kongolo.
# Retrieving results for response 188: alta floresta.
# Retrieving results for response 189: castro.
# Retrieving results for response 190: salalah.
# Retrieving results for response 191: bekhtery.
# Retrieving results for response 192: yellowknife.
# Retrieving results for response 193: kavieng.
# Retrieving results for response 194: kodinsk.
# Retrieving results for response 195: zhanaozen.
# Retrieving results for response 196: sataua.
# No Results for sataua... skipping
# Retrieving results for response 197: ulety.
# Retrieving results for response 198: tucurui.
# Retrieving results for response 199: edd.
# Retrieving results for response 200: mandera.
# Retrieving results for response 201: ambilobe.
# Retrieving results for response 202: kieta.
# Retrieving results for response 203: georgetown.
# Retrieving results for response 204: talcahuano.
# Retrieving results for response 205: gushikawa.
# Retrieving results for response 206: srednekolymsk.
# Retrieving results for response 207: hondo.
# Retrieving results for response 208: aklavik.
# Retrieving results for response 209: vila velha.
# Retrieving results for response 210: ondjiva.
# Retrieving results for response 211: westpunt.
# No Results for westpunt... skipping
# Retrieving results for response 212: isangel.
# Retrieving results for response 213: tautira.
# Retrieving results for response 214: mandalgovi.
# Retrieving results for response 215: baculin.
# Retrieving results for response 216: chapeco.
# Retrieving results for response 217: nemuro.
# Retrieving results for response 218: jiayuguan.
# Retrieving results for response 219: mar del plata.
# Retrieving results for response 220: nome.
# Retrieving results for response 221: buala.
# Retrieving results for response 222: rabo de peixe.
# Retrieving results for response 223: khirkiya.
# Retrieving results for response 224: vestmannaeyjar.
# Retrieving results for response 225: hofn.
# Retrieving results for response 226: san jose.
# Retrieving results for response 227: lakes entrance.
# Retrieving results for response 228: husavik.
# Retrieving results for response 229: leningradskiy.
# Retrieving results for response 230: piotrkow trybunalski.
# Retrieving results for response 231: zhigansk.
# Retrieving results for response 232: zyryanka.
# Retrieving results for response 233: yuksekova.
# Retrieving results for response 234: tsihombe.
# No Results for tsihombe... skipping
# Retrieving results for response 235: belyy yar.
# Retrieving results for response 236: lyantonde.
# Retrieving results for response 237: kuche.
# No Results for kuche... skipping
# Retrieving results for response 238: yulara.
# Retrieving results for response 239: sentyabrskiy.
# No Results for sentyabrskiy... skipping
# Retrieving results for response 240: tessalit.
# Retrieving results for response 241: puerto escondido.
# Retrieving results for response 242: ust-nera.
# Retrieving results for response 243: khetri.
# Retrieving results for response 244: biak.
# Retrieving results for response 245: lagoa.
# Retrieving results for response 246: presidencia roque saenz pena.
# Retrieving results for response 247: dongsheng.
# Retrieving results for response 248: moron.
# Retrieving results for response 249: te anau.
# Retrieving results for response 250: grand river south east.
# No Results for grand river south east... skipping
# Retrieving results for response 251: fort frances.
# Retrieving results for response 252: pasni.
# Retrieving results for response 253: stonewall.
# Retrieving results for response 254: tecoanapa.
# Retrieving results for response 255: omaruru.
# Retrieving results for response 256: thinadhoo.
# Retrieving results for response 257: fortuna.
# Retrieving results for response 258: sorland.
# Retrieving results for response 259: san policarpo.
# Retrieving results for response 260: chuy.
# Retrieving results for response 261: makakilo city.
# Retrieving results for response 262: diamantina.
# Retrieving results for response 263: kavaratti.
# Retrieving results for response 264: nokaneng.
# Retrieving results for response 265: tigil.
# Retrieving results for response 266: elko.
# Retrieving results for response 267: ruatoria.
# No Results for ruatoria... skipping
# Retrieving results for response 268: nuuk.
# Retrieving results for response 269: itaituba.
# Retrieving results for response 270: cukai.
# Retrieving results for response 271: grindavik.
# Retrieving results for response 272: solano.
# Retrieving results for response 273: opuwo.
# Retrieving results for response 274: meulaboh.
# Retrieving results for response 275: utiroa.
# No Results for utiroa... skipping
# Retrieving results for response 276: lanaken.
# Retrieving results for response 277: cherskiy.
# Retrieving results for response 278: batemans bay.
# Retrieving results for response 279: naze.
# Retrieving results for response 280: samusu.
# No Results for samusu... skipping
# Retrieving results for response 281: ipora.
# Retrieving results for response 282: huarmey.
# Retrieving results for response 283: severodvinsk.
# Retrieving results for response 284: mungwi.
# Retrieving results for response 285: novoagansk.
# Retrieving results for response 286: hami.
# Retrieving results for response 287: sivas.
# Retrieving results for response 288: saint anthony.
# Retrieving results for response 289: whitehorse.
# Retrieving results for response 290: roald.
# Retrieving results for response 291: amderma.
# No Results for amderma... skipping
# Retrieving results for response 292: brooks.
# Retrieving results for response 293: marzuq.
# Retrieving results for response 294: zambezi.
# Retrieving results for response 295: benguela.
# Retrieving results for response 296: caravelas.
# Retrieving results for response 297: tocopilla.
# Retrieving results for response 298: hlotse.
# Retrieving results for response 299: mana.
# Retrieving results for response 300: buchanan.
# Retrieving results for response 301: shingu.
# Retrieving results for response 302: cidreira.
# Retrieving results for response 303: westport.
# Retrieving results for response 304: fort saint james.
# Retrieving results for response 305: mount isa.
# Retrieving results for response 306: vyartsilya.
# Retrieving results for response 307: koraput.
# Retrieving results for response 308: bairiki.
# Retrieving results for response 309: blythe.
# Retrieving results for response 310: kruisfontein.
# Retrieving results for response 311: guangyuan.
# Retrieving results for response 312: pisco.
# Retrieving results for response 313: moyale.
# Retrieving results for response 314: bama.
# Retrieving results for response 315: imbituba.
# Retrieving results for response 316: karratha.
# Retrieving results for response 317: pangody.
# Retrieving results for response 318: umzimvubu.
# No Results for umzimvubu... skipping
# Retrieving results for response 319: barabinsk.
# Retrieving results for response 320: cumaribo.
# No Results for cumaribo... skipping
# Retrieving results for response 321: hengshan.
# Retrieving results for response 322: anastacio.
# Retrieving results for response 323: bolshaya irba.
# No Results for bolshaya irba... skipping
# Retrieving results for response 324: rapid valley.
# Retrieving results for response 325: mehran.
# Retrieving results for response 326: santa rosa del sur.
# Retrieving results for response 327: northam.
# Retrieving results for response 328: martapura.
# Retrieving results for response 329: mayo.
# Retrieving results for response 330: acajutla.
# Retrieving results for response 331: maturin.
# Retrieving results for response 332: abu zabad.
# Retrieving results for response 333: aflu.
# No Results for aflu... skipping
# Retrieving results for response 334: kabwe.
# Retrieving results for response 335: rawson.
# Retrieving results for response 336: butembo.
# Retrieving results for response 337: torbay.
# Retrieving results for response 338: necochea.
# Retrieving results for response 339: cap-aux-meules.
# Retrieving results for response 340: haines junction.
# Retrieving results for response 341: balikpapan.
# Retrieving results for response 342: sembe.
# Retrieving results for response 343: isilkul.
# Retrieving results for response 344: hamza.
# Retrieving results for response 345: redmond.
# Retrieving results for response 346: manzil jamil.
# No Results for manzil jamil... skipping
# Retrieving results for response 347: longyearbyen.
# Retrieving results for response 348: ilulissat.
# Retrieving results for response 349: nantucket.
# Retrieving results for response 350: harper.
# Retrieving results for response 351: luganville.
# Retrieving results for response 352: olinda.
# Retrieving results for response 353: el cope.
# Retrieving results for response 354: popondetta.
# Retrieving results for response 355: delta del tigre.
# Retrieving results for response 356: puerto del rosario.
# Retrieving results for response 357: barsesti.
# No Results for barsesti... skipping
# Retrieving results for response 358: tongren.
# Retrieving results for response 359: mokhsogollokh.
# Retrieving results for response 360: tilichiki.
# Retrieving results for response 361: santa rosa.
# Retrieving results for response 362: san cristobal.
# Retrieving results for response 363: yumen.
# Retrieving results for response 364: nadym.
# Retrieving results for response 365: bo.
# No Results for bo... skipping
# Retrieving results for response 366: egvekinot.
# Retrieving results for response 367: waingapu.
# Retrieving results for response 368: dudinka.
# Retrieving results for response 369: chigorodo.
# Retrieving results for response 370: ushtobe.
# Retrieving results for response 371: kidal.
# Retrieving results for response 372: neuquen.
# Retrieving results for response 373: adrar.
# Retrieving results for response 374: prince rupert.
# Retrieving results for response 375: chernyshevskiy.
# Retrieving results for response 376: waipawa.
# Retrieving results for response 377: yurimaguas.
# Retrieving results for response 378: kurilsk.
# Retrieving results for response 379: kharabali.
# Retrieving results for response 380: thouars.
# Retrieving results for response 381: ulaanbaatar.
# Retrieving results for response 382: bandarbeyla.
# Retrieving results for response 383: nabire.
# Retrieving results for response 384: tiznit.
# Retrieving results for response 385: svetlaya.
# Retrieving results for response 386: trairi.
# Retrieving results for response 387: samalaeulu.
# No Results for samalaeulu... skipping
# Retrieving results for response 388: hasaki.
# Retrieving results for response 389: vieste.
# Retrieving results for response 390: fort nelson.
# Retrieving results for response 391: ambagarh chauki.
# Retrieving results for response 392: sandwick.
# Retrieving results for response 393: palmer.
# Retrieving results for response 394: derzhavinsk.
# Retrieving results for response 395: acapulco.
# Retrieving results for response 396: mariel.
# Retrieving results for response 397: marcona.
# No Results for marcona... skipping
# Retrieving results for response 398: doha.
# Retrieving results for response 399: gimli.
# Retrieving results for response 400: korla.
# Retrieving results for response 401: yuanping.
# Retrieving results for response 402: kouango.
# Retrieving results for response 403: klaksvik.
# Retrieving results for response 404: ixtapa.
# Retrieving results for response 405: cairns.
# Retrieving results for response 406: the valley.
# Retrieving results for response 407: abu samrah.
# Retrieving results for response 408: ulladulla.
# Retrieving results for response 409: chapais.
# Retrieving results for response 410: catamarca.
# Retrieving results for response 411: mwinilunga.
# Retrieving results for response 412: melendugno.
# Retrieving results for response 413: howard springs.
# Retrieving results for response 414: katsuura.
# Retrieving results for response 415: bonoua.
# Retrieving results for response 416: cuenca.
# Retrieving results for response 417: pringsewu.
# Retrieving results for response 418: poum.
# Retrieving results for response 419: krasnoye.
# Retrieving results for response 420: kankan.
# Retrieving results for response 421: novomikhaylovskiy.
# Retrieving results for response 422: gbongan.
# Retrieving results for response 423: merauke.
# Retrieving results for response 424: richards bay.
# Retrieving results for response 425: strezhevoy.
# Retrieving results for response 426: chagda.
# No Results for chagda... skipping
# Retrieving results for response 427: hailey.
# Retrieving results for response 428: cam pha.
# No Results for cam pha... skipping
# Retrieving results for response 429: ballina.
# Retrieving results for response 430: halalo.
# No Results for halalo... skipping
# Retrieving results for response 431: labuan.
# Retrieving results for response 432: nevesinje.
# Retrieving results for response 433: vangaindrano.
# Retrieving results for response 434: iqaluit.
# Retrieving results for response 435: alofi.
# Retrieving results for response 436: sinnamary.
# Retrieving results for response 437: matara.
# Retrieving results for response 438: palabuhanratu.
# No Results for palabuhanratu... skipping
# Retrieving results for response 439: port macquarie.
# Retrieving results for response 440: sarangani.
# Retrieving results for response 441: tumannyy.
# No Results for tumannyy... skipping
# Retrieving results for response 442: nador.
# Retrieving results for response 443: la ronge.
# Retrieving results for response 444: santiago del estero.
# Retrieving results for response 445: ijaki.
# No Results for ijaki... skipping
# Retrieving results for response 446: grand gaube.
# Retrieving results for response 447: saleaula.
# No Results for saleaula... skipping
# Retrieving results for response 448: najran.
# Retrieving results for response 449: saint-joseph.
# Retrieving results for response 450: fomboni.
# Retrieving results for response 451: karpogory.
# Retrieving results for response 452: armeria.
# Retrieving results for response 453: jackson.
# Retrieving results for response 454: attawapiskat.
# No Results for attawapiskat... skipping
# Retrieving results for response 455: zeya.
# Retrieving results for response 456: sao joao da barra.
# Retrieving results for response 457: coihaique.
# Retrieving results for response 458: araceli.
# Retrieving results for response 459: kapoeta.
# Retrieving results for response 460: junin.
# Retrieving results for response 461: bulgan.
# Retrieving results for response 462: phalaborwa.
# Retrieving results for response 463: kazachinskoye.
# Retrieving results for response 464: coquimbo.
# Retrieving results for response 465: mount darwin.
# Retrieving results for response 466: trincomalee.
# Retrieving results for response 467: lovozero.
# Retrieving results for response 468: ahipara.
# Retrieving results for response 469: atasu.
# Retrieving results for response 470: plettenberg bay.
# Retrieving results for response 471: taltal.
# Retrieving results for response 472: ruwi.
# Retrieving results for response 473: west helena.
# Retrieving results for response 474: san antonio.
# Retrieving results for response 475: sarakhs.
# Retrieving results for response 476: kuala terengganu.
# Retrieving results for response 477: tolaga bay.
# Retrieving results for response 478: winnemucca.
# Retrieving results for response 479: saint-leu.
# Retrieving results for response 480: bongor.
# Retrieving results for response 481: kawalu.
# Retrieving results for response 482: tuy hoa.
# Retrieving results for response 483: falealupo.
# No Results for falealupo... skipping
# Retrieving results for response 484: goderich.
# Retrieving results for response 485: miracema do tocantins.
# Retrieving results for response 486: markova.
# Retrieving results for response 487: mendahara.
# No Results for mendahara... skipping
# Retrieving results for response 488: aykhal.
# Retrieving results for response 489: manavgat.
# Retrieving results for response 490: jiexiu.
# Retrieving results for response 491: sinop.
# Retrieving results for response 492: kayankulam.
# Retrieving results for response 493: straumen.
# Retrieving results for response 494: dasoguz.
# Retrieving results for response 495: jizan.
# Retrieving results for response 496: sri aman.
# Retrieving results for response 497: taoudenni.
# Retrieving results for response 498: qui nhon.
# Retrieving results for response 499: longlac.
# No Results for longlac... skipping
# Retrieving results for response 500: sokolac.
# Retrieving results for response 501: dongning.
# Retrieving results for response 502: marsa matruh.
# Retrieving results for response 503: oksfjord.
# Retrieving results for response 504: pauini.
# Retrieving results for response 505: mao.
# Retrieving results for response 506: iquique.
# Retrieving results for response 507: carroll.
# Retrieving results for response 508: casas grandes.
# Retrieving results for response 509: litoral del san juan.
# No Results for litoral del san juan... skipping
# Retrieving results for response 510: visby.
# Retrieving results for response 511: asayita.
# No Results for asayita... skipping
# Retrieving results for response 512: abu kamal.
# Retrieving results for response 513: ternate.
# Retrieving results for response 514: nanortalik.
# Retrieving results for response 515: nioro.
# Retrieving results for response 516: manokwari.
# Retrieving results for response 517: alaca.
# Retrieving results for response 518: eurajoki.
# Retrieving results for response 519: purranque.
# Retrieving results for response 520: vardo.
# Retrieving results for response 521: russell.
# Retrieving results for response 522: ngunguru.
# Retrieving results for response 523: laplace.
# Retrieving results for response 524: kashmor.
# Retrieving results for response 525: roebourne.
# Retrieving results for response 526: carauari.
# Retrieving results for response 527: lorengau.
# Retrieving results for response 528: kosh-agach.
# Retrieving results for response 529: sehithwa.
# Retrieving results for response 530: hay river.
# Retrieving results for response 531: ostrovnoy.
# Retrieving results for response 532: ermoupolis.
# Retrieving results for response 533: kibondo.
# Retrieving results for response 534: todos santos.
# Retrieving results for response 535: tabiauea.
# No Results for tabiauea... skipping
# Retrieving results for response 536: moerai.
# Retrieving results for response 537: villa florida.
# Retrieving results for response 538: port blair.
# Retrieving results for response 539: torata.
# Retrieving results for response 540: la rioja.
# Retrieving results for response 541: atar.
# Retrieving results for response 542: flinders.
# Retrieving results for response 543: saint cloud.
# Retrieving results for response 544: praia.
# Retrieving results for response 545: buin.
# Retrieving results for response 546: mirina.
# No Results for mirina... skipping
# Retrieving results for response 547: vila franca do campo.
# Retrieving results for response 548: suzun.
# Retrieving results for response 549: saint-pierre.
# Retrieving results for response 550: tanda.
# Retrieving results for response 551: east stroudsburg.
# Retrieving results for response 552: petropavl.
# Retrieving results for response 553: kohima.
# Retrieving results for response 554: port moresby.
# Retrieving results for response 555: yeppoon.
# Retrieving results for response 556: independence.
# Retrieving results for response 557: nishihara.
# Retrieving results for response 558: ribeirao branco.
# Retrieving results for response 559: ancud.
# Retrieving results for response 560: wencheng.
# Retrieving results for response 561: gizo.
# Retrieving results for response 562: artyom.
# Retrieving results for response 563: karlskrona.
# Retrieving results for response 564: abnub.
# Retrieving results for response 565: beloha.
# Retrieving results for response 566: yanam.
# Retrieving results for response 567: asuncion.
# Retrieving results for response 568: anadyr.
# Retrieving results for response 569: sao jose da coroa grande.
# Retrieving results for response 570: muros.
# Retrieving results for response 571: siverek.
# Retrieving results for response 572: khandyga.
# Retrieving results for response 573: ondorhaan.
# No Results for ondorhaan... skipping
# Retrieving results for response 574: vila.
# Retrieving results for response 575: marand.
# Retrieving results for response 576: koslan.
# Retrieving results for response 577: ixhuatan.
# Retrieving results for response 578: stykkisholmur.
# Retrieving results for response 579: napasar.
# Retrieving results for response 580: kijang.
# Retrieving results for response 581: foso.
# Retrieving results for response 582: lukovetskiy.
# Retrieving results for response 583: salinas.
# Retrieving results for response 584: talaya.
# Retrieving results for response 585: pinega.
# Retrieving results for response 586: rawannawi.
# No Results for rawannawi... skipping
# Retrieving results for response 587: novobeysugskaya.
# Retrieving results for response 588: novyy urengoy.
# Retrieving results for response 589: formosa do rio preto.
# Retrieving results for response 590: itacare.
# Retrieving results for response 591: palu.
# Retrieving results for response 592: beyneu.
# Retrieving results for response 593: gornyak.
# Retrieving results for response 594: nordby.
# Retrieving results for response 595: shepsi.
# Retrieving results for response 596: quesnel.
# Retrieving results for response 597: makaha.
# Retrieving results for response 598: bad ischl.
# Retrieving results for response 599: cabedelo.
# Retrieving results for response 600: lavumisa.
# Retrieving results for response 601: kozulka.
# Retrieving results for response 602: havre.
# Retrieving results for response 603: jalu.
# Retrieving results for response 604: vaitape.
# Retrieving results for response 605: wanning.
# Retrieving results for response 606: scarborough.
# Retrieving results for response 607: qaqortoq.
# Retrieving results for response 608: urucui.
# Retrieving results for response 609: bonavista.
# Retrieving results for response 610: diamantino.
# Retrieving results for response 611: mareeba.
# ------------------------------------
# Data Retrieval Complete

# %%
# Export as csv file 
weather_df.to_csv(output_data_file)

# Display dataframe 
weather_df
# Out:
#             City      Lat     Long Max Temp Humidity Cloudiness Wind Speed  \
# 0    east london -33.0153  27.9116   295.78       74         88       2.65
# 1         viedma -40.8135 -62.9967   297.04       39          0       7.12
# 2         atuona     -9.8 -139.033   299.19       72          4       4.74
# 3      taolanaro
# 4           lebu -37.6167   -73.65    289.3       79          0       1.09
# ..           ...      ...      ...      ...      ...        ...        ...
# 607     qaqortoq  60.7167 -46.0333   263.15       52         99       2.06
# 608       urucui  -7.2294 -44.5561    298.1       81        100       1.38
# 609    bonavista  48.6499 -53.1147   277.15      100         95       1.03
# 610   diamantino -14.4086 -56.4461   298.05       81        100       0.94
# 611      mareeba      -17  145.433   304.82       70         40       3.09
#
#     Country        Date
# 0        ZA  1612490148
# 1        AR  1612490149
# 2        PF  1612489888
# 3
# 4        CL  1612489915
# ..      ...         ...
# 607      GL  1612490235
# 608      BR  1612490235
# 609      CA  1612490236
# 610      BR  1612490236
# 611      AU  1612490236
#
# [612 rows x 9 columns]

# %%
# Convert data types to numerical and get statistical summary 
numerical_df = weather_df[['Lat', 'Long', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date']]
numerical_df = numerical_df.apply(pd.to_numeric)
numerical_df.describe()
# Out:
#               Lat        Long    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  558.000000  558.000000  558.000000  558.000000  558.000000  558.000000
# mean    18.659045   18.137553  283.135699   74.130824   52.664875    3.635448
# std     34.191252   92.336534   17.564149   18.143822   39.983128    2.641633
# min    -54.800000 -179.166700  231.150000    1.000000    0.000000    0.180000
# 25%    -10.505825  -60.614675  272.150000   67.000000    8.250000    1.540000
# 50%     22.226450   23.238150  289.185000   78.000000   51.500000    3.090000
# 75%     47.280575  101.958850  297.150000   87.000000   94.000000    5.022500
# max     78.218600  178.416700  308.150000  100.000000  100.000000   15.430000
#
#                Date
# count  5.580000e+02
# mean   1.612490e+09
# std    9.909810e+01
# min    1.612489e+09
# 25%    1.612490e+09
# 50%    1.612490e+09
# 75%    1.612490e+09
# max    1.612490e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100% and drop by index if there are any outliers.

high_humid = numerical_df.loc[numerical_df['Humidity'] > 100].index

if len(high_humid) == 0:
    print('No cities have a humidity > 100%')
if len(high_humid) > 0:
    weather_df = weather_df.drop(high_humid)
    display(weather_df)
# Out:
# No cities have a humidity > 100%

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
