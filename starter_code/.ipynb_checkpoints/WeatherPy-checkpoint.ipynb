# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Import API Key
from api_keys import weather_api_key

# Get API url 
weather_url = "http://api.openweathermap.org/data/2.5/weather?"

# Create empty columns 
weather_df = pd.DataFrame()
weather_df['City'] = cities
weather_df['Lat'] = ""
weather_df['Long'] = ""
weather_df['Max Temp'] = ""
weather_df['Humidity'] = ""
weather_df['Cloudiness'] = ""
weather_df['Wind Speed'] = ""
weather_df['Country'] = ""
weather_df['Date'] = ""

#City name formatting 
weather_df['City'] = weather_df['City'].str.title()

weather_df
# Out:
#                  City Lat Long Max Temp Humidity Cloudiness Wind Speed  \
# 0            Coquimbo
# 1           Chlorakas
# 2             Mataura
# 3                Hilo
# 4         Nizhneyansk
# ..                ...  ..  ...      ...      ...        ...        ...
# 624            Ovalle
# 625             Mions
# 626  Glenwood Springs
# 627         Mutsamudu
# 628        Valparaiso
#
#     Country Date
# 0
# 1
# 2
# 3
# 4
# ..      ...  ...
# 624
# 625
# 626
# 627
# 628
#
# [629 rows x 9 columns]

# %%
## API calls 

print('Beginning Data Retrieval')
print('------------------------------------')

# Loop through cities and get weather. Pass if city has no data.
for index, row in weather_df.iterrows():
    
    # Get city name from dataframe 
    city = row['City']
    
    # Generate query url 
    query_url = weather_url + 'q=' + city + '&appid=' + weather_api_key
    
    try:
        # Retrieve data 
        response = requests.get(query_url).json()
        
        # Add response to column 
        print(f"Retrieving results for response {index}: {city}.")
        weather_df.loc[index, 'Lat'] = response['coord']['lat']
        weather_df.loc[index, 'Long'] = response['coord']['lon']
        weather_df.loc[index, 'Max Temp'] = response['main']['temp_max']
        weather_df.loc[index, 'Humidity'] = response['main']['humidity']
        weather_df.loc[index, 'Cloudiness'] = response['clouds']['all']
        weather_df.loc[index, 'Wind Speed'] = response['wind']['speed']
        weather_df.loc[index, 'Country'] = response['sys']['country']
        weather_df.loc[index, 'Date'] = response['dt']
    
    # Skip results with no data
    except KeyError:
        print(f'No Results for {city}... skipping')
    
    
print('------------------------------------')
print('Data Retrieval Complete')
# Out:
# Beginning Data Retrieval
# ------------------------------------
# Retrieving results for response 0: Coquimbo.
# Retrieving results for response 1: Chlorakas.
# Retrieving results for response 2: Mataura.
# Retrieving results for response 3: Hilo.
# Retrieving results for response 4: Nizhneyansk.
# No Results for Nizhneyansk... skipping
# Retrieving results for response 5: Phan Thiet.
# Retrieving results for response 6: Ushuaia.
# Retrieving results for response 7: Busselton.
# Retrieving results for response 8: Upernavik.
# Retrieving results for response 9: Kodinar.
# Retrieving results for response 10: Marcona.
# No Results for Marcona... skipping
# Retrieving results for response 11: Leningradskiy.
# Retrieving results for response 12: Umzimvubu.
# No Results for Umzimvubu... skipping
# Retrieving results for response 13: Punta Arenas.
# Retrieving results for response 14: Avarua.
# Retrieving results for response 15: Jamestown.
# Retrieving results for response 16: Belyy Yar.
# Retrieving results for response 17: Juneau.
# Retrieving results for response 18: Georgetown.
# Retrieving results for response 19: Albany.
# Retrieving results for response 20: Port Alfred.
# Retrieving results for response 21: Anadyr.
# Retrieving results for response 22: Vagur.
# Retrieving results for response 23: Souillac.
# Retrieving results for response 24: Bredasdorp.
# Retrieving results for response 25: Alofi.
# Retrieving results for response 26: Vaini.
# Retrieving results for response 27: Barrow.
# Retrieving results for response 28: Belmonte.
# Retrieving results for response 29: Cape Town.
# Retrieving results for response 30: Zhuanghe.
# Retrieving results for response 31: Belushya Guba.
# No Results for Belushya Guba... skipping
# Retrieving results for response 32: Rikitea.
# Retrieving results for response 33: Dikson.
# Retrieving results for response 34: Lyuban.
# Retrieving results for response 35: Longyearbyen.
# Retrieving results for response 36: Alyangula.
# Retrieving results for response 37: Vradiyivka.
# Retrieving results for response 38: Puerto Narino.
# Retrieving results for response 39: Kamenskoye.
# No Results for Kamenskoye... skipping
# Retrieving results for response 40: Praia Da Vitoria.
# Retrieving results for response 41: Tuktoyaktuk.
# Retrieving results for response 42: Faanui.
# Retrieving results for response 43: Kaeo.
# Retrieving results for response 44: Viedma.
# Retrieving results for response 45: Shubarshi.
# Retrieving results for response 46: Tumannyy.
# No Results for Tumannyy... skipping
# Retrieving results for response 47: Cabo San Lucas.
# Retrieving results for response 48: Mahebourg.
# Retrieving results for response 49: New Norfolk.
# Retrieving results for response 50: Vaitupu.
# No Results for Vaitupu... skipping
# Retrieving results for response 51: Amapa.
# Retrieving results for response 52: Castro.
# Retrieving results for response 53: Vardo.
# Retrieving results for response 54: Thinadhoo.
# Retrieving results for response 55: Qaanaaq.
# Retrieving results for response 56: Klaksvik.
# Retrieving results for response 57: Port Augusta.
# Retrieving results for response 58: Nanakuli.
# Retrieving results for response 59: Chernyshevskiy.
# Retrieving results for response 60: Sao Joao Do Piaui.
# Retrieving results for response 61: Saldanha.
# Retrieving results for response 62: Cherskiy.
# Retrieving results for response 63: Kamenka.
# Retrieving results for response 64: Curup.
# Retrieving results for response 65: Krasnogorskoye.
# Retrieving results for response 66: Severo-Kurilsk.
# Retrieving results for response 67: Chingirlau.
# Retrieving results for response 68: Akyab.
# Retrieving results for response 69: Port Elizabeth.
# Retrieving results for response 70: Maun.
# Retrieving results for response 71: Taolanaro.
# No Results for Taolanaro... skipping
# Retrieving results for response 72: Saint-Joseph.
# Retrieving results for response 73: San Felipe.
# Retrieving results for response 74: Hermanus.
# Retrieving results for response 75: Tonantins.
# Retrieving results for response 76: Erzin.
# Retrieving results for response 77: Tiksi.
# Retrieving results for response 78: Kulhudhuffushi.
# Retrieving results for response 79: Kabelvag.
# Retrieving results for response 80: Hithadhoo.
# Retrieving results for response 81: East London.
# Retrieving results for response 82: Banjar.
# Retrieving results for response 83: Vao.
# Retrieving results for response 84: Thompson.
# Retrieving results for response 85: Meulaboh.
# Retrieving results for response 86: Bluff.
# Retrieving results for response 87: Yulara.
# Retrieving results for response 88: Clyde River.
# Retrieving results for response 89: Saskylakh.
# Retrieving results for response 90: Aklavik.
# Retrieving results for response 91: Nishihara.
# Retrieving results for response 92: Bengkulu.
# Retrieving results for response 93: Antalaha.
# Retrieving results for response 94: Qasigiannguit.
# Retrieving results for response 95: Fenoarivo.
# Retrieving results for response 96: Tasiilaq.
# Retrieving results for response 97: Asyut.
# Retrieving results for response 98: Hobart.
# Retrieving results for response 99: Coihaique.
# Retrieving results for response 100: Honjo.
# Retrieving results for response 101: Khandyga.
# Retrieving results for response 102: Bichura.
# Retrieving results for response 103: Bethel.
# Retrieving results for response 104: Artyk.
# No Results for Artyk... skipping
# Retrieving results for response 105: Tupik.
# Retrieving results for response 106: Barentsburg.
# No Results for Barentsburg... skipping
# Retrieving results for response 107: Jiuquan.
# Retrieving results for response 108: Palmerston.
# Retrieving results for response 109: Namibe.
# Retrieving results for response 110: Puerto Ayora.
# Retrieving results for response 111: Kirakira.
# Retrieving results for response 112: Vestmannaeyjar.
# Retrieving results for response 113: Severobaykalsk.
# Retrieving results for response 114: Likhoy.
# Retrieving results for response 115: Illoqqortoormiut.
# No Results for Illoqqortoormiut... skipping
# Retrieving results for response 116: Dukat.
# Retrieving results for response 117: Grand River South East.
# No Results for Grand River South East... skipping
# Retrieving results for response 118: Lavrentiya.
# Retrieving results for response 119: Salalah.
# Retrieving results for response 120: Victoria.
# Retrieving results for response 121: Grand Gaube.
# Retrieving results for response 122: Torbay.
# Retrieving results for response 123: Banda Aceh.
# Retrieving results for response 124: Haines Junction.
# Retrieving results for response 125: George Town.
# Retrieving results for response 126: Saint-Leu.
# Retrieving results for response 127: Darovskoy.
# Retrieving results for response 128: Aykhal.
# Retrieving results for response 129: Aviles.
# Retrieving results for response 130: Tshikapa.
# Retrieving results for response 131: Paita.
# Retrieving results for response 132: Shurugwi.
# Retrieving results for response 133: Quelimane.
# Retrieving results for response 134: Kodiak.
# Retrieving results for response 135: Isabela.
# Retrieving results for response 136: Lebu.
# Retrieving results for response 137: Ponta Do Sol.
# Retrieving results for response 138: Yellowknife.
# Retrieving results for response 139: Atuona.
# Retrieving results for response 140: Kysyl-Syr.
# Retrieving results for response 141: Gorin.
# Retrieving results for response 142: Fortuna.
# Retrieving results for response 143: Samusu.
# No Results for Samusu... skipping
# Retrieving results for response 144: Abu Dhabi.
# Retrieving results for response 145: Millau.
# Retrieving results for response 146: Mys Shmidta.
# No Results for Mys Shmidta... skipping
# Retrieving results for response 147: Mount Gambier.
# Retrieving results for response 148: Coruripe.
# Retrieving results for response 149: Cimislia.
# Retrieving results for response 150: Butaritari.
# Retrieving results for response 151: Champerico.
# Retrieving results for response 152: Khatanga.
# Retrieving results for response 153: Constitucion.
# Retrieving results for response 154: Hamilton.
# Retrieving results for response 155: Iberia.
# Retrieving results for response 156: Half Moon Bay.
# Retrieving results for response 157: Gamba.
# Retrieving results for response 158: Kapaa.
# Retrieving results for response 159: Otradnoye.
# Retrieving results for response 160: Viligili.
# No Results for Viligili... skipping
# Retrieving results for response 161: Chokurdakh.
# Retrieving results for response 162: Yenagoa.
# Retrieving results for response 163: Selikhino.
# Retrieving results for response 164: Sabha.
# Retrieving results for response 165: Provideniya.
# Retrieving results for response 166: Touros.
# Retrieving results for response 167: Tidore.
# No Results for Tidore... skipping
# Retrieving results for response 168: Esperance.
# Retrieving results for response 169: Mongo.
# Retrieving results for response 170: Saint-Philippe.
# Retrieving results for response 171: Drolshagen.
# Retrieving results for response 172: Puerto Penasco.
# Retrieving results for response 173: Gander.
# Retrieving results for response 174: Chuy.
# Retrieving results for response 175: Paramonga.
# Retrieving results for response 176: Sambava.
# Retrieving results for response 177: Mana.
# Retrieving results for response 178: Narsaq.
# Retrieving results for response 179: Daman.
# Retrieving results for response 180: Portland.
# Retrieving results for response 181: Fort Nelson.
# Retrieving results for response 182: Macaboboni.
# No Results for Macaboboni... skipping
# Retrieving results for response 183: Belaya Gora.
# Retrieving results for response 184: Moquegua.
# Retrieving results for response 185: Necochea.
# Retrieving results for response 186: Kruisfontein.
# Retrieving results for response 187: General Elizardo Aquino.
# Retrieving results for response 188: Tsihombe.
# No Results for Tsihombe... skipping
# Retrieving results for response 189: Itarema.
# Retrieving results for response 190: Rocha.
# Retrieving results for response 191: Kahului.
# Retrieving results for response 192: Antofagasta.
# Retrieving results for response 193: Luderitz.
# Retrieving results for response 194: El Faiyum.
# No Results for El Faiyum... skipping
# Retrieving results for response 195: Norilsk.
# Retrieving results for response 196: Valdemarpils.
# Retrieving results for response 197: Katsuura.
# Retrieving results for response 198: Mumford.
# Retrieving results for response 199: Lodja.
# Retrieving results for response 200: Hearst.
# Retrieving results for response 201: Lagoa.
# Retrieving results for response 202: Pevek.
# Retrieving results for response 203: Husavik.
# Retrieving results for response 204: Ayan.
# Retrieving results for response 205: Avera.
# Retrieving results for response 206: Raudeberg.
# Retrieving results for response 207: Bonthe.
# Retrieving results for response 208: Mount Isa.
# Retrieving results for response 209: Neiafu.
# Retrieving results for response 210: Muli.
# Retrieving results for response 211: Paradwip.
# No Results for Paradwip... skipping
# Retrieving results for response 212: Bairiki.
# Retrieving results for response 213: San Miguel.
# Retrieving results for response 214: Hue.
# Retrieving results for response 215: Nainpur.
# Retrieving results for response 216: Garachine.
# Retrieving results for response 217: Bathsheba.
# Retrieving results for response 218: Hasaki.
# Retrieving results for response 219: Mega.
# Retrieving results for response 220: Swellendam.
# Retrieving results for response 221: Tuburan.
# Retrieving results for response 222: Umbertide.
# Retrieving results for response 223: Jardim.
# Retrieving results for response 224: Santa Cruz Cabralia.
# Retrieving results for response 225: Ancud.
# Retrieving results for response 226: Laguna.
# Retrieving results for response 227: Lompoc.
# Retrieving results for response 228: Kedrovyy.
# Retrieving results for response 229: Fuerte Olimpo.
# Retrieving results for response 230: Hope.
# Retrieving results for response 231: Morros.
# Retrieving results for response 232: Beckley.
# Retrieving results for response 233: Parana.
# Retrieving results for response 234: Moroni.
# Retrieving results for response 235: Bethanien.
# Retrieving results for response 236: Buala.
# Retrieving results for response 237: Krasnyy Chikoy.
# Retrieving results for response 238: Egvekinot.
# Retrieving results for response 239: Tournon-Sur-Rhone.
# Retrieving results for response 240: Airai.
# Retrieving results for response 241: Ongandjera.
# Retrieving results for response 242: Toora-Khem.
# Retrieving results for response 243: Buta.
# Retrieving results for response 244: Ardesen.
# Retrieving results for response 245: Guerrero Negro.
# Retrieving results for response 246: Juegang.
# Retrieving results for response 247: Olafsvik.
# Retrieving results for response 248: Carnarvon.
# Retrieving results for response 249: Bubaque.
# Retrieving results for response 250: Bilibino.
# Retrieving results for response 251: Veyrier.
# Retrieving results for response 252: Novokizhinginsk.
# Retrieving results for response 253: Saleaula.
# No Results for Saleaula... skipping
# Retrieving results for response 254: Naryan-Mar.
# Retrieving results for response 255: Rubio.
# Retrieving results for response 256: Tateyama.
# Retrieving results for response 257: Sentyabrskiy.
# No Results for Sentyabrskiy... skipping
# Retrieving results for response 258: Tombouctou.
# Retrieving results for response 259: Kangaatsiaq.
# Retrieving results for response 260: Arraial Do Cabo.
# Retrieving results for response 261: Karoi.
# Retrieving results for response 262: Port Blair.
# Retrieving results for response 263: Mar Del Plata.
# Retrieving results for response 264: Kamiiso.
# Retrieving results for response 265: Santa Rosa.
# Retrieving results for response 266: Tutayev.
# Retrieving results for response 267: Attawapiskat.
# No Results for Attawapiskat... skipping
# Retrieving results for response 268: Grand-Santi.
# Retrieving results for response 269: Yining.
# Retrieving results for response 270: Dzerzhinsk.
# Retrieving results for response 271: Bambous Virieux.
# Retrieving results for response 272: Lakes Entrance.
# Retrieving results for response 273: Brainerd.
# Retrieving results for response 274: Azul.
# Retrieving results for response 275: Kavieng.
# Retrieving results for response 276: Djambala.
# Retrieving results for response 277: Geraldton.
# Retrieving results for response 278: Bambanglipuro.
# Retrieving results for response 279: Saint George.
# Retrieving results for response 280: Shitanjing.
# Retrieving results for response 281: Qaqortoq.
# Retrieving results for response 282: Algiers.
# Retrieving results for response 283: Oni.
# Retrieving results for response 284: Minot.
# Retrieving results for response 285: Saint Anthony.
# Retrieving results for response 286: Mudanya.
# Retrieving results for response 287: Dali.
# Retrieving results for response 288: Semey.
# Retrieving results for response 289: Iqaluit.
# Retrieving results for response 290: Guarapari.
# Retrieving results for response 291: Mungaoli.
# Retrieving results for response 292: Sume.
# Retrieving results for response 293: Boyle.
# Retrieving results for response 294: Dingle.
# Retrieving results for response 295: Kabanjahe.
# Retrieving results for response 296: Tiznit.
# Retrieving results for response 297: Santa Maria.
# Retrieving results for response 298: Slave Lake.
# Retrieving results for response 299: Palmer.
# Retrieving results for response 300: Goderich.
# Retrieving results for response 301: Shubarkuduk.
# Retrieving results for response 302: Tabou.
# Retrieving results for response 303: Tura.
# Retrieving results for response 304: Ponoka.
# Retrieving results for response 305: Vernon.
# Retrieving results for response 306: Chekhov.
# Retrieving results for response 307: Norman Wells.
# Retrieving results for response 308: Mangrol.
# Retrieving results for response 309: Ribeira Grande.
# Retrieving results for response 310: Kavaratti.
# Retrieving results for response 311: Port Macquarie.
# Retrieving results for response 312: Tomatlan.
# Retrieving results for response 313: Marion.
# Retrieving results for response 314: Luanda.
# Retrieving results for response 315: Uttaradit.
# Retrieving results for response 316: Itaporanga.
# Retrieving results for response 317: Neuquen.
# Retrieving results for response 318: Okha.
# Retrieving results for response 319: Acarau.
# Retrieving results for response 320: Ishigaki.
# Retrieving results for response 321: Isla Mujeres.
# Retrieving results for response 322: Marathon.
# Retrieving results for response 323: Ust-Tsilma.
# Retrieving results for response 324: Nieuw Amsterdam.
# Retrieving results for response 325: Karratha.
# Retrieving results for response 326: Tibati.
# Retrieving results for response 327: Lorengau.
# Retrieving results for response 328: Atbasar.
# Retrieving results for response 329: Bud.
# Retrieving results for response 330: Mapiripan.
# Retrieving results for response 331: Kamaishi.
# Retrieving results for response 332: College.
# Retrieving results for response 333: Muisne.
# Retrieving results for response 334: Komsomolskiy.
# Retrieving results for response 335: Port Victoria.
# Retrieving results for response 336: Ondjiva.
# Retrieving results for response 337: La Palma.
# Retrieving results for response 338: Burica.
# No Results for Burica... skipping
# Retrieving results for response 339: Moron.
# Retrieving results for response 340: Karuzi.
# Retrieving results for response 341: Ambodifototra.
# No Results for Ambodifototra... skipping
# Retrieving results for response 342: Omsukchan.
# Retrieving results for response 343: Amderma.
# No Results for Amderma... skipping
# Retrieving results for response 344: Nemuro.
# Retrieving results for response 345: Nikolskoye.
# Retrieving results for response 346: La Ronge.
# Retrieving results for response 347: Nome.
# Retrieving results for response 348: Mocambique.
# No Results for Mocambique... skipping
# Retrieving results for response 349: Tazovskiy.
# Retrieving results for response 350: Yacuiba.
# Retrieving results for response 351: Grindavik.
# Retrieving results for response 352: Akdepe.
# Retrieving results for response 353: Sao Joao Da Barra.
# Retrieving results for response 354: Yar-Sale.
# Retrieving results for response 355: Kuytun.
# Retrieving results for response 356: Catuday.
# Retrieving results for response 357: Muravlenko.
# Retrieving results for response 358: Henties Bay.
# Retrieving results for response 359: Sioux Lookout.
# Retrieving results for response 360: Los Reyes.
# Retrieving results for response 361: Thurso.
# Retrieving results for response 362: Lichinga.
# Retrieving results for response 363: Turukhansk.
# Retrieving results for response 364: Mehamn.
# Retrieving results for response 365: Kautokeino.
# Retrieving results for response 366: Copiapo.
# Retrieving results for response 367: Almaznyy.
# Retrieving results for response 368: Atherton.
# Retrieving results for response 369: Kupang.
# Retrieving results for response 370: Ola.
# Retrieving results for response 371: Altay.
# Retrieving results for response 372: Bousso.
# Retrieving results for response 373: Rockland.
# Retrieving results for response 374: Namatanai.
# Retrieving results for response 375: Saint-Augustin.
# Retrieving results for response 376: Gazli.
# Retrieving results for response 377: Jaciara.
# Retrieving results for response 378: Berlevag.
# Retrieving results for response 379: Kotka.
# Retrieving results for response 380: San Patricio.
# Retrieving results for response 381: Southbridge.
# Retrieving results for response 382: Aswan.
# Retrieving results for response 383: Hambantota.
# Retrieving results for response 384: Naze.
# Retrieving results for response 385: Constantine.
# Retrieving results for response 386: Makakilo City.
# Retrieving results for response 387: Morehead.
# Retrieving results for response 388: Barrhead.
# Retrieving results for response 389: Sooke.
# Retrieving results for response 390: Mugla.
# Retrieving results for response 391: Broome.
# Retrieving results for response 392: Saint-Andre-Les-Vergers.
# Retrieving results for response 393: Bolungarvik.
# No Results for Bolungarvik... skipping
# Retrieving results for response 394: Vila Velha.
# Retrieving results for response 395: Eldorado.
# Retrieving results for response 396: Hay River.
# Retrieving results for response 397: Zhangye.
# Retrieving results for response 398: Leh.
# Retrieving results for response 399: Kumertau.
# Retrieving results for response 400: Rio Grande.
# Retrieving results for response 401: Wanning.
# Retrieving results for response 402: Tilichiki.
# Retrieving results for response 403: Nanortalik.
# Retrieving results for response 404: Kiunga.
# Retrieving results for response 405: Cockburn Town.
# Retrieving results for response 406: Soyo.
# Retrieving results for response 407: Atikokan.
# Retrieving results for response 408: Lipin Bor.
# Retrieving results for response 409: Pedra Azul.
# Retrieving results for response 410: Burnie.
# Retrieving results for response 411: Caconde.
# Retrieving results for response 412: Vestmanna.
# Retrieving results for response 413: Markova.
# Retrieving results for response 414: San Carlos De Bariloche.
# Retrieving results for response 415: Batagay-Alyta.
# Retrieving results for response 416: Tarauaca.
# Retrieving results for response 417: Dubrovnik.
# Retrieving results for response 418: Saint-Francois.
# Retrieving results for response 419: Periban.
# No Results for Periban... skipping
# Retrieving results for response 420: Zhezkazgan.
# Retrieving results for response 421: Ulaanbaatar.
# Retrieving results for response 422: Maragogi.
# Retrieving results for response 423: Canoas.
# Retrieving results for response 424: Saint-Pierre.
# Retrieving results for response 425: Derzhavinsk.
# Retrieving results for response 426: Shingu.
# Retrieving results for response 427: Kot Diji.
# Retrieving results for response 428: Port Hardy.
# Retrieving results for response 429: Itupiranga.
# Retrieving results for response 430: Molchanovo.
# Retrieving results for response 431: Sant Julia De Loria.
# Retrieving results for response 432: Katherine.
# Retrieving results for response 433: Axim.
# Retrieving results for response 434: Palabuhanratu.
# No Results for Palabuhanratu... skipping
# Retrieving results for response 435: Glomfjord.
# Retrieving results for response 436: Sawakin.
# Retrieving results for response 437: Burlington.
# Retrieving results for response 438: Tadine.
# Retrieving results for response 439: Niquelandia.
# Retrieving results for response 440: Kinshasa.
# Retrieving results for response 441: Labuhan.
# Retrieving results for response 442: Hofn.
# Retrieving results for response 443: Xining.
# Retrieving results for response 444: Selma.
# Retrieving results for response 445: Enumclaw.
# Retrieving results for response 446: Zaysan.
# Retrieving results for response 447: Cidreira.
# Retrieving results for response 448: Sao Felix Do Xingu.
# Retrieving results for response 449: Havelock.
# Retrieving results for response 450: Bilma.
# Retrieving results for response 451: Tocopilla.
# Retrieving results for response 452: Pozo Colorado.
# Retrieving results for response 453: Xiongzhou.
# Retrieving results for response 454: Kamalasai.
# Retrieving results for response 455: Walvis Bay.
# Retrieving results for response 456: Mvuma.
# Retrieving results for response 457: Sampit.
# Retrieving results for response 458: Bafq.
# Retrieving results for response 459: Balad.
# Retrieving results for response 460: Ocos.
# Retrieving results for response 461: Dunedin.
# Retrieving results for response 462: Pak Phanang.
# Retrieving results for response 463: Loubomo.
# Retrieving results for response 464: Xucheng.
# Retrieving results for response 465: Ilulissat.
# Retrieving results for response 466: Geresk.
# No Results for Geresk... skipping
# Retrieving results for response 467: Isangel.
# Retrieving results for response 468: Haapiti.
# Retrieving results for response 469: Collie.
# Retrieving results for response 470: Ende.
# Retrieving results for response 471: Rio Pomba.
# Retrieving results for response 472: Turki.
# Retrieving results for response 473: Smidovich.
# Retrieving results for response 474: Svetlaya.
# Retrieving results for response 475: Inhambane.
# Retrieving results for response 476: Codrington.
# Retrieving results for response 477: Saint-Paul.
# Retrieving results for response 478: Benghazi.
# Retrieving results for response 479: Daru.
# Retrieving results for response 480: Pedras De Fogo.
# Retrieving results for response 481: Deputatskiy.
# Retrieving results for response 482: Palu.
# Retrieving results for response 483: Gazimurskiy Zavod.
# Retrieving results for response 484: Teguldet.
# Retrieving results for response 485: Qui Nhon.
# Retrieving results for response 486: Teluknaga.
# Retrieving results for response 487: Oussouye.
# Retrieving results for response 488: Padang.
# Retrieving results for response 489: Port-De-Paix.
# No Results for Port-De-Paix... skipping
# Retrieving results for response 490: Forrest City.
# Retrieving results for response 491: Superior.
# Retrieving results for response 492: Straumen.
# Retrieving results for response 493: Tjome.
# Retrieving results for response 494: Bay Saint Louis.
# Retrieving results for response 495: Beira.
# Retrieving results for response 496: Tala.
# Retrieving results for response 497: Lamesa.
# Retrieving results for response 498: Puerto Suarez.
# Retrieving results for response 499: Ondorhaan.
# No Results for Ondorhaan... skipping
# Retrieving results for response 500: Fare.
# Retrieving results for response 501: Les Cayes.
# Retrieving results for response 502: Basyanovskiy.
# No Results for Basyanovskiy... skipping
# Retrieving results for response 503: Kisac.
# Retrieving results for response 504: Vanimo.
# Retrieving results for response 505: Jacareacanga.
# Retrieving results for response 506: Road Town.
# Retrieving results for response 507: Lasa.
# Retrieving results for response 508: Dudinka.
# Retrieving results for response 509: Kpandae.
# Retrieving results for response 510: Safaga.
# Retrieving results for response 511: Chara.
# Retrieving results for response 512: Vila Franca Do Campo.
# Retrieving results for response 513: Lashma.
# Retrieving results for response 514: Atambua.
# Retrieving results for response 515: Hami.
# Retrieving results for response 516: Ozernovskiy.
# Retrieving results for response 517: Cheuskiny.
# No Results for Cheuskiny... skipping
# Retrieving results for response 518: Sotnikovo.
# Retrieving results for response 519: Sumbe.
# Retrieving results for response 520: San Vicente.
# Retrieving results for response 521: Zalantun.
# Retrieving results for response 522: Baixa Grande.
# Retrieving results for response 523: Westport.
# Retrieving results for response 524: Asasa.
# Retrieving results for response 525: Oksfjord.
# Retrieving results for response 526: Portobelo.
# Retrieving results for response 527: Hualmay.
# Retrieving results for response 528: Halalo.
# No Results for Halalo... skipping
# Retrieving results for response 529: Kaitangata.
# Retrieving results for response 530: Hihifo.
# No Results for Hihifo... skipping
# Retrieving results for response 531: Smithers.
# Retrieving results for response 532: Vostok.
# Retrieving results for response 533: Lagos.
# Retrieving results for response 534: Shache.
# Retrieving results for response 535: Inza.
# Retrieving results for response 536: Arcachon.
# Retrieving results for response 537: Golubitskaya.
# Retrieving results for response 538: Ekhabi.
# Retrieving results for response 539: Havre-Saint-Pierre.
# Retrieving results for response 540: Tigil.
# Retrieving results for response 541: Mahad.
# Retrieving results for response 542: Aberystwyth.
# Retrieving results for response 543: Ndjole.
# Retrieving results for response 544: Mercedes.
# Retrieving results for response 545: Marawi.
# Retrieving results for response 546: Katobu.
# Retrieving results for response 547: Wewak.
# Retrieving results for response 548: Dossor.
# Retrieving results for response 549: Umm Kaddadah.
# Retrieving results for response 550: Weatherford.
# Retrieving results for response 551: Awbari.
# Retrieving results for response 552: Cumaribo.
# No Results for Cumaribo... skipping
# Retrieving results for response 553: Ketchikan.
# Retrieving results for response 554: Puerto Parra.
# Retrieving results for response 555: Gazanjyk.
# Retrieving results for response 556: Sola.
# Retrieving results for response 557: Nova Aurora.
# Retrieving results for response 558: Taltal.
# Retrieving results for response 559: Utiroa.
# No Results for Utiroa... skipping
# Retrieving results for response 560: Mackay.
# Retrieving results for response 561: Rafai.
# Retrieving results for response 562: Koumac.
# Retrieving results for response 563: Bystrice Nad Pernstejnem.
# Retrieving results for response 564: Vaitape.
# Retrieving results for response 565: Del Rio.
# Retrieving results for response 566: Mecca.
# Retrieving results for response 567: Sao Gabriel Da Cachoeira.
# Retrieving results for response 568: Bandar-E Lengeh.
# Retrieving results for response 569: Russell.
# Retrieving results for response 570: Bitung.
# Retrieving results for response 571: Sorvag.
# No Results for Sorvag... skipping
# Retrieving results for response 572: Korla.
# Retrieving results for response 573: Korhogo.
# Retrieving results for response 574: Warqla.
# No Results for Warqla... skipping
# Retrieving results for response 575: Dese.
# Retrieving results for response 576: Biloela.
# Retrieving results for response 577: Preobrazheniye.
# Retrieving results for response 578: Cheremukhovo.
# Retrieving results for response 579: Mwense.
# Retrieving results for response 580: Bintulu.
# Retrieving results for response 581: Yazykovo.
# Retrieving results for response 582: Cayenne.
# Retrieving results for response 583: Bulgan.
# Retrieving results for response 584: Virginia Beach.
# Retrieving results for response 585: Hervey Bay.
# Retrieving results for response 586: Jalu.
# Retrieving results for response 587: Nalut.
# Retrieving results for response 588: Sao Filipe.
# Retrieving results for response 589: Kita.
# Retrieving results for response 590: Rundu.
# Retrieving results for response 591: Puerto Leguizamo.
# Retrieving results for response 592: Jizan.
# Retrieving results for response 593: Jinchang.
# Retrieving results for response 594: Ibra.
# Retrieving results for response 595: Tokmak.
# Retrieving results for response 596: Harmanli.
# Retrieving results for response 597: Imperia.
# Retrieving results for response 598: Huilong.
# Retrieving results for response 599: Campbell River.
# Retrieving results for response 600: Kurilsk.
# Retrieving results for response 601: Talnakh.
# Retrieving results for response 602: Lolua.
# No Results for Lolua... skipping
# Retrieving results for response 603: Lumberton.
# Retrieving results for response 604: Kurumkan.
# Retrieving results for response 605: Zarate.
# Retrieving results for response 606: Tabas.
# Retrieving results for response 607: Negele.
# No Results for Negele... skipping
# Retrieving results for response 608: Yangambi.
# Retrieving results for response 609: Ust-Ishim.
# Retrieving results for response 610: Arnedo.
# Retrieving results for response 611: Andros Town.
# Retrieving results for response 612: Kieta.
# Retrieving results for response 613: Omboue.
# Retrieving results for response 614: Angol.
# Retrieving results for response 615: Poum.
# Retrieving results for response 616: Tacna.
# Retrieving results for response 617: Yantzaza.
# Retrieving results for response 618: Matagami.
# Retrieving results for response 619: Pangody.
# Retrieving results for response 620: Lawton.
# Retrieving results for response 621: Sorong.
# Retrieving results for response 622: Bourg-Les-Valence.
# Retrieving results for response 623: Innisfail.
# Retrieving results for response 624: Ovalle.
# Retrieving results for response 625: Mions.
# Retrieving results for response 626: Glenwood Springs.
# Retrieving results for response 627: Mutsamudu.
# No Results for Mutsamudu... skipping
# Retrieving results for response 628: Valparaiso.
# ------------------------------------
# Data Retrieval Complete

# %%
# Export as csv file 
weather_df.to_csv(output_data_file)

# Display dataframe 
weather_df
# Out:
#                  City      Lat     Long Max Temp Humidity Cloudiness  \
# 0            Coquimbo -29.9533 -71.3436   289.15       88         90
# 1           Chlorakas  34.8042  32.4083   284.15       87         20
# 2             Mataura -46.1927  168.864   296.32       39         99
# 3                Hilo  19.7297  -155.09   295.15       73         40
# 4         Nizhneyansk
# ..                ...      ...      ...      ...      ...        ...
# 624            Ovalle -30.5983 -71.2003   288.47       79          0
# 625             Mions  45.6643   4.9499   284.15      100        100
# 626  Glenwood Springs  39.5505 -107.325   269.26       85         90
# 627         Mutsamudu
# 628        Valparaiso -33.0393 -71.6273   290.37       78         68
#
#     Wind Speed Country        Date
# 0         3.09      CL  1612491840
# 1         3.09      CY  1612492068
# 2         1.16      NZ  1612492069
# 3          7.2      US  1612491930
# 4
# ..         ...     ...         ...
# 624       0.99      CL  1612492157
# 625       1.03      FR  1612492157
# 626       4.12      US  1612491879
# 627
# 628       1.25      CL  1612492157
#
# [629 rows x 9 columns]

# %%
# Convert data types to numerical and get statistical summary 
numerical_df = weather_df[['Lat', 'Long', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date']]
numerical_df = numerical_df.apply(pd.to_numeric)
numerical_df.describe().round(2)
# Out:
#           Lat    Long  Max Temp  Humidity  Cloudiness  Wind Speed  \
# count  585.00  585.00    585.00    585.00      585.00      585.00
# mean    19.82   16.96    282.68     75.85       53.47        3.53
# std     33.54   89.98     17.67     17.35       40.67        2.65
# min    -54.80 -179.17    232.15     17.00        0.00        0.06
# 25%     -9.01  -59.43    271.57     67.00        6.00        1.54
# 50%     24.09   20.07    288.72     80.00       61.00        2.90
# 75%     48.68  100.18    297.04     88.00       96.00        4.74
# max     78.22  178.42    308.15    100.00      100.00       15.71
#
#                Date
# count  5.850000e+02
# mean   1.612492e+09
# std    7.820000e+01
# min    1.612491e+09
# 25%    1.612492e+09
# 50%    1.612492e+09
# 75%    1.612492e+09
# max    1.612492e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100% and drop by index if there are any outliers.

high_humid = numerical_df.loc[numerical_df['Humidity'] > 100].index

if len(high_humid) == 0:
    print('No cities have a humidity > 100%')
if len(high_humid) > 0:
    weather_df = weather_df.drop(high_humid)
    display(weather_df)
# Out:
# No cities have a humidity > 100%

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Get X and Y values
latitude = numerical_df['Lat']
temp = numerical_df['Max Temp']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(latitude, temp, marker='.', color='orange')
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (K)')
plt.grid(True)

# Save as png 
plt.savefig('../output_data/lat_temp.png', format='png')

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Get humidity data
humidity = numerical_df['Humidity']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(latitude, humidity, marker='.', color='red')
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Save as png 
plt.savefig('../output_data/lat_humid.png', format='png')

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Get cloudiness data
clouds = numerical_df['Cloudiness']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(latitude, clouds, marker='.', color='green')
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Save as png 
plt.savefig('../output_data/lat_cloud.png', format='png')

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Get wind speed data
wind = numerical_df['Wind Speed']

# Plot 
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(latitude, temp, marker='.', color='b')
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid(True)

# Save as png 
plt.savefig('../output_data/lat_wind.png', format='png')

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
numerical_df
# Out:
#          Lat      Long  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   -29.9533  -71.3436    289.15      88.0        90.0        3.09
# 1    34.8042   32.4083    284.15      87.0        20.0        3.09
# 2   -46.1927  168.8643    296.32      39.0        99.0        1.16
# 3    19.7297 -155.0900    295.15      73.0        40.0        7.20
# 4        NaN       NaN       NaN       NaN         NaN         NaN
# ..       ...       ...       ...       ...         ...         ...
# 624 -30.5983  -71.2003    288.47      79.0         0.0        0.99
# 625  45.6643    4.9499    284.15     100.0       100.0        1.03
# 626  39.5505 -107.3248    269.26      85.0        90.0        4.12
# 627      NaN       NaN       NaN       NaN         NaN         NaN
# 628 -33.0393  -71.6273    290.37      78.0        68.0        1.25
#
#              Date
# 0    1.612492e+09
# 1    1.612492e+09
# 2    1.612492e+09
# 3    1.612492e+09
# 4             NaN
# ..            ...
# 624  1.612492e+09
# 625  1.612492e+09
# 626  1.612492e+09
# 627           NaN
# 628  1.612492e+09
#
# [629 rows x 7 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Select Northern Hemisphere data
north = numerical_df.loc[numerical_df['Lat'] > 0]

# Get NH Max temp and latitude and convert to farenheit
north_temp = north['Max Temp']
north_temp_f = (north_temp - 273.15) * 9/5 + 32
north_lat = north['Lat']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(north_lat, north_temp_f, marker='.', color='crimson')
plt.title('Northern Hemisphere City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(True)

# Regression
r_sq = st.pearsonr(north_lat, north_temp_f)
r_sq = r_sq[0].round(2)
NH_temp_r = f"r² = {r_sq}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(north_lat, north_temp_f)
north_temp_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
regression = north_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(north_lat, regression)
plt.annotate(north_temp_eq, (50,80), fontsize=12, color='black')
plt.annotate(NH_temp_r, (50,70), fontsize=12, color='black')
plt.show()

# Save as png 
plt.savefig('../output_data/NH_temp.png', format='png')

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Select Northern Hemisphere data
south = numerical_df.loc[numerical_df['Lat'] < 0]

# Get NH Max temp and latitude and convert to F
south_temp = south['Max Temp']
south_temp = (south_temp - 273.15) * 9/5 + 32
south_lat = south['Lat']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(south_lat, south_temp, marker='.', color='b')
plt.title('Southern Hemisphere City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(True)

# Regression
s_r_sq = st.pearsonr(south_lat, south_temp)
s_r_sq = s_r_sq[0].round(2)
sh_temp_r = f"r² = {s_r_sq}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(south_lat, south_temp)
south_temp_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
sh_regression = south_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(south_lat, sh_regression)
plt.annotate(south_temp_eq, (-50,90), fontsize=12, color='black')
plt.annotate(sh_temp_r, (-50,85), fontsize=12, color='black')
plt.show()

# Save as png 
plt.savefig('../output_data/SH_temp.png', format='png')

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Get NH humidity 
nh_humidity = north['Humidity']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(north_lat, nh_humidity, marker='.', color='lightcoral')
plt.title('Northern Hemisphere City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Regression
nh_hum_r = st.pearsonr(north_lat, nh_humidity)
nh_hum_r = nh_hum_r[0].round(2)
nh_hum_r = f"r² = {nh_hum_r}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(north_lat, nh_humidity)
nh_hum_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
nh_hum_regress = north_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(north_lat, nh_hum_regress)
plt.annotate(nh_hum_eq, (50,40), fontsize=14, color='black')
plt.annotate(nh_hum_r, (50,35), fontsize=14, color='black')
plt.show()

# Save as png 
plt.savefig('../output_data/NH_humidity.png', format='png')

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Get SH humidity 
sh_humidity = south['Humidity']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(south_lat, sh_humidity, marker='.', color='tomato')
plt.title('Southern Hemisphere City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Regression
sh_hum_r = st.pearsonr(south_lat, sh_humidity)
sh_hum_r = sh_hum_r[0].round(2)
sh_hum_r = f"r² = {sh_hum_r}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(south_lat, sh_humidity)
sh_hum_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
sh_hum_regress = south_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(south_lat, sh_hum_regress)
plt.annotate(sh_hum_eq, (-20,45), fontsize=14, color='black')
plt.annotate(sh_hum_r, (-20,40), fontsize=14, color='black')
plt.show()

# Save as png 
plt.savefig('../output_data/SH_humidity.png', format='png')

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Get NH cloudiness 
nh_clouds = north['Cloudiness']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(north_lat, nh_clouds, marker='.', color='b')
plt.title('Northern Hemisphere City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Regression
nh_clouds_r = st.pearsonr(north_lat, nh_clouds)
nh_clouds_r = nh_clouds_r[0].round(2)
nh_clouds_r = f"r² = {nh_clouds_r}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(north_lat, nh_clouds)
nh_clouds_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
nh_clouds_regress = north_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(north_lat, nh_clouds_regress)
plt.annotate(nh_clouds_eq, (65,30), fontsize=15, color='darkred')
plt.annotate(nh_clouds_r, (65,20), fontsize=15, color='darkred')
plt.show()

# Save as png 
plt.savefig('../output_data/NH_clouds.png', format='png')

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Get SH cloudiness 
sh_clouds = south['Cloudiness']

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(south_lat, sh_clouds, marker='.', color='b')
plt.title('Southern Hemisphere City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Regression
sh_clouds_r = st.pearsonr(south_lat, sh_clouds)
sh_clouds_r = sh_clouds_r[0].round(2)
sh_clouds_r = f"r² = {sh_clouds_r}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(south_lat, sh_clouds)
sh_clouds_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
sh_clouds_regress = south_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(south_lat, sh_clouds_regress)
plt.annotate(sh_clouds_eq, (-50,10), fontsize=14, color='darkred')
plt.annotate(sh_clouds_r, (-50,2), fontsize=14, color='darkred')
plt.show()

# Save as png 
plt.savefig('../output_data/SH_clouds.png', format='png')

plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Get NH wind speed, convert to mph 
nh_wind = north['Wind Speed']
nh_wind = nh_wind * 2.237

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(north_lat, nh_wind, marker='.', color='b')
plt.title('Northern Hemisphere City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)

# Regression
nh_wind_r = st.pearsonr(north_lat, nh_wind)
nh_wind_r = nh_wind_r[0].round(2)
nh_wind_r = f"r² = {nh_wind_r}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(north_lat, nh_wind)
nh_wind_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
nh_wind_regress = north_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(north_lat, nh_wind_regress)
plt.annotate(nh_wind_eq, (10,30), fontsize=13, color='black')
plt.annotate(nh_wind_r, (10,25), fontsize=13, color='black')
plt.show()

# Save as png 
plt.savefig('../output_data/NH_wind.png', format='png')

plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Get SH wind speed, convert to mph 
sh_wind = south['Wind Speed']
sb_wind = sh_wind * 2.237

# Plot
fig, ax = plt.subplots(figsize=(6,5))
plt.scatter(south_lat, sh_wind, marker='.', color='crimson')
plt.title('Southern Hemisphere City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)

# Regression
sh_wind_r = st.pearsonr(south_lat, sh_wind)
sh_wind_r = sh_wind_r[0].round(2)
sh_wind_r = f"r² = {sh_wind_r}"

# Linear regression
(slope, intercept, rvalue, pvalue, std) = linregress(south_lat, sh_wind)
sh_wind_eq = 'y = ' + str(slope.round(2)) + 'x + ' + str((intercept.round(2)))
sh_wind_regress = south_lat * slope + intercept

# Add equation and regression line to figure 
plt.plot(south_lat, sh_wind_regress)
plt.annotate(sh_wind_eq, (-20,14), fontsize=15, color='black')
plt.annotate(sh_wind_r, (-20,12), fontsize=15, color='black')
plt.show()

# Save as png 
plt.savefig('../output_data/SH_wind.png', format='png')

plt.show()
